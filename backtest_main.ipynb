# %%
import datetime
import numpy as np
import pandas as pd

import sys
sys.path.append('C:\\project\\code')
import setting

# %%
import cleandata_2

# %% [markdown]
# # 0. Prepare monthly data

# %%
import prepare_data
data = pd.read_hdf('../input/full_data_0218_washed.h5', key='data')
print('Done reading h5...')

daily_return, monthly_return = prepare_data.main_total_vol(data, path='../input/from_prepare_data/')

# %%
del daily_return, monthly_return

# %% [markdown]
# # 1. Create and save investable univesre

# %%
cleandata_2.create_invest_universe(setting.datapath+'full_data_0218_washed.h5',
                           setting.datapath+'investable_universe_test.npy',
                           datetime.datetime(1962, 1, 1),
                           datetime.datetime(2001, 1, 1))
# Out:
# Read-in...
# Read done...
# Data preclean done...
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# Data saved

# %% [markdown]
# # 2. Create portfolio weights

# %%
import form_portfolio

# %% [markdown]
# ## 2.1 Vol from Monthly
# ### 2.1.1 Total Vol

# %%
file_list = ['M_VOL', 'L_VOL_12M', 'L_VOL_18M', 'L_VOL_24M', 'L_VOL_36M', 'MKTCAP_M']
list_execute = [['M_VOL_lag'], 
                ['L_VOL_12M_lag_lag'], ['L_VOL_18M_lag_lag'], ['L_VOL_24M_lag_lag'], ['L_VOL_36M_lag_lag'],
                ['M_VOL_lag', 'L_VOL_12M_lag_lag'],
                ['M_VOL_lag', 'L_VOL_18M_lag_lag'],
                ['M_VOL_lag', 'L_VOL_24M_lag_lag'],
                ['M_VOL_lag', 'L_VOL_36M_lag_lag']
                ]
date_list = [datetime.datetime(1965, 2, 1), datetime.datetime(2016, 12, 31)]

for nyse_break in [True, False]:
    form_portfolio.form_portfolio(files=file_list, investable_universe_npy='investable_universe_0221.npy',
                              nyse_permno_xlsx='NYSE PERMNO.xlsx', list_execute=list_execute,
                              nyse_break=nyse_break, startdate=date_list[0], enddate=date_list[1])
# Out:
# Portfolio formed for _M_VOL_lag
# Portfolio formed for _L_VOL_12M_lag_lag
# Portfolio formed for _L_VOL_18M_lag_lag
# Portfolio formed for _L_VOL_24M_lag_lag
# Portfolio formed for _L_VOL_36M_lag_lag
# Portfolio formed for _M_VOL_lag_L_VOL_12M_lag_lag
# Portfolio formed for _M_VOL_lag_L_VOL_18M_lag_lag
# Portfolio formed for _M_VOL_lag_L_VOL_24M_lag_lag
# Portfolio formed for _M_VOL_lag_L_VOL_36M_lag_lag
# Portfolio formed for _M_VOL_lag
# Portfolio formed for _L_VOL_12M_lag_lag
# Portfolio formed for _L_VOL_18M_lag_lag
# Portfolio formed for _L_VOL_24M_lag_lag
# Portfolio formed for _L_VOL_36M_lag_lag
# Portfolio formed for _M_VOL_lag_L_VOL_12M_lag_lag
# Portfolio formed for _M_VOL_lag_L_VOL_18M_lag_lag
# Portfolio formed for _M_VOL_lag_L_VOL_24M_lag_lag
# Portfolio formed for _M_VOL_lag_L_VOL_36M_lag_lag

# %% [markdown]
# ### 2.1.2 Idio Vol

# %%
file_list = ['FF_M_VOL', 'FF_L_VOL_12M', 'FF_L_VOL_18M', 'FF_L_VOL_24M', 'FF_L_VOL_36M', 'MKTCAP_M']
list_execute = [['FF_M_VOL_lag'], 
                ['FF_L_VOL_12M_lag_lag'], ['FF_L_VOL_18M_lag_lag'], ['FF_L_VOL_24M_lag_lag'], ['FF_L_VOL_36M_lag_lag'],
                ['FF_M_VOL_lag', 'FF_L_VOL_12M_lag_lag'],
                ['FF_M_VOL_lag', 'FF_L_VOL_18M_lag_lag'],
                ['FF_M_VOL_lag', 'FF_L_VOL_24M_lag_lag'],
                ['FF_M_VOL_lag', 'FF_L_VOL_36M_lag_lag']
                ]
date_list = [datetime.datetime(1965, 2, 1), datetime.datetime(2016, 12, 31)]

for nyse_break in [True, False]:
    form_portfolio.form_portfolio(files=file_list, investable_universe_npy='investable_universe_0221.npy',
                              nyse_permno_xlsx='NYSE PERMNO.xlsx', list_execute=list_execute,
                              nyse_break=nyse_break, startdate=date_list[0], enddate=date_list[1])
# Out:
# Portfolio formed for _FF_M_VOL_lag
# Portfolio formed for _FF_L_VOL_12M_lag_lag
# Portfolio formed for _FF_L_VOL_18M_lag_lag
# Portfolio formed for _FF_L_VOL_24M_lag_lag
# Portfolio formed for _FF_L_VOL_36M_lag_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_12M_lag_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_18M_lag_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_24M_lag_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_36M_lag_lag
# Portfolio formed for _FF_M_VOL_lag
# Portfolio formed for _FF_L_VOL_12M_lag_lag
# Portfolio formed for _FF_L_VOL_18M_lag_lag
# Portfolio formed for _FF_L_VOL_24M_lag_lag
# Portfolio formed for _FF_L_VOL_36M_lag_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_12M_lag_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_18M_lag_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_24M_lag_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_36M_lag_lag

# %%
# origianl short selling measures

# %%
# # file_list = ['M_VOL', 'L_VOL_12M', 'MKTCAP_M', 'DS_ratio', 'UtilisationByQuantity']
# # list_execute = [['M_VOL_lag'], ['L_VOL_12M_lag'], ['M_VOL_lag', 'L_VOL_12M_lag'],
# #                 ['M_VOL_lag', 'DS_ratio_lag'],  ['M_VOL_lag', 'UtilisationByQuantity_lag']]

# file_list = ['M_VOL', 'L_VOL_24W', 'FF_M_VOL', 'FF_L_VOL_24W', 'MKTCAP_M', 'DS_ratio', 'UtilisationByQuantity']

# list_execute = [
# #     ['M_VOL_lag'], 
#      ['M_VOL_lag', 'L_VOL_24W_lag_lag'],
#                 ['FF_M_VOL_lag'],
#                 ['FF_M_VOL_lag', 'FF_L_VOL_24W_lag_lag'],
# #                 ['M_VOL_lag', 'DS_ratio_lag'],  ['M_VOL_lag', 'UtilisationByQuantity_lag'],
#                 ['FF_M_VOL_lag', 'DS_ratio_lag'],  ['FF_M_VOL_lag', 'UtilisationByQuantity_lag']]

# date_list = [datetime.datetime(2004, 6, 1), datetime.datetime(2016, 12, 31)]

# for nyse_break in [True, False]:
#     form_portfolio.form_portfolio(files=file_list, investable_universe_npy='investable_universe_0221.npy',
#                               nyse_permno_xlsx='NYSE PERMNO.xlsx', list_execute=list_execute,
#                               nyse_break=nyse_break, startdate=date_list[0], enddate=date_list[1])
# Out:
# Portfolio formed for _M_VOL_lag_L_VOL_24W_lag_lag
# Portfolio formed for _FF_M_VOL_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_24W_lag_lag
# Portfolio formed for _FF_M_VOL_lag_DS_ratio_lag
# Portfolio formed for _FF_M_VOL_lag_UtilisationByQuantity_lag
# Portfolio formed for _M_VOL_lag_L_VOL_24W_lag_lag
# Portfolio formed for _FF_M_VOL_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_24W_lag_lag
# Portfolio formed for _FF_M_VOL_lag_DS_ratio_lag
# Portfolio formed for _FF_M_VOL_lag_UtilisationByQuantity_lag

# %% [markdown]
# ## 2.2 Vol from Weekly return
# ### 2.2.1 total Vol

# %%
file_list = ['M_VOL', 'L_VOL_24W', 'L_VOL_48W', 'L_VOL_72W', 'MKTCAP_M']
list_execute = [['M_VOL_lag'], 
                ['L_VOL_24W_lag_lag'], ['L_VOL_48W_lag_lag'], ['L_VOL_72W_lag_lag'], 
                ['M_VOL_lag', 'L_VOL_24W_lag_lag'],
                ['M_VOL_lag', 'L_VOL_48W_lag_lag'],
                ['M_VOL_lag', 'L_VOL_72W_lag_lag']]
date_list = [datetime.datetime(1963, 7, 1), datetime.datetime(2016, 12, 31)]

for nyse_break in [True, False]:
    form_portfolio.form_portfolio(files=file_list, investable_universe_npy='investable_universe_0221.npy',
                              nyse_permno_xlsx='NYSE PERMNO.xlsx', list_execute=list_execute,
                              nyse_break=nyse_break, startdate=date_list[0], enddate=date_list[1])
# Out:
# Portfolio formed for _M_VOL_lag
# Portfolio formed for _L_VOL_24W_lag_lag
# Portfolio formed for _L_VOL_48W_lag_lag
# Portfolio formed for _L_VOL_72W_lag_lag
# Portfolio formed for _M_VOL_lag_L_VOL_24W_lag_lag
# Portfolio formed for _M_VOL_lag_L_VOL_48W_lag_lag
# Portfolio formed for _M_VOL_lag_L_VOL_72W_lag_lag
# Portfolio formed for _M_VOL_lag
# Portfolio formed for _L_VOL_24W_lag_lag
# Portfolio formed for _L_VOL_48W_lag_lag
# Portfolio formed for _L_VOL_72W_lag_lag
# Portfolio formed for _M_VOL_lag_L_VOL_24W_lag_lag
# Portfolio formed for _M_VOL_lag_L_VOL_48W_lag_lag
# Portfolio formed for _M_VOL_lag_L_VOL_72W_lag_lag

# %% [markdown]
# ### 2.2.2 Idio Vol

# %%
file_list = ['FF_M_VOL', 'FF_L_VOL_24W', 'FF_L_VOL_48W', 'FF_L_VOL_72W','MKTCAP_M']
list_execute = [['FF_M_VOL_lag'], 
                ['FF_L_VOL_24W_lag_lag'],
                ['FF_L_VOL_48W_lag_lag'],
                ['FF_L_VOL_72W_lag_lag'],
                ['FF_M_VOL_lag', 'FF_L_VOL_24W_lag_lag'],
                ['FF_M_VOL_lag', 'FF_L_VOL_48W_lag_lag'],
                ['FF_M_VOL_lag', 'FF_L_VOL_72W_lag_lag']
                ]
date_list = [datetime.datetime(1963, 7, 1), datetime.datetime(2016, 12, 31)]

for nyse_break in [True, False]:
    form_portfolio.form_portfolio(files=file_list, investable_universe_npy='investable_universe_0221.npy',
                              nyse_permno_xlsx='NYSE PERMNO.xlsx', list_execute=list_execute,
                              nyse_break=nyse_break, startdate=date_list[0], enddate=date_list[1])
# Out:
# Portfolio formed for _FF_M_VOL_lag
# Portfolio formed for _FF_L_VOL_24W_lag_lag
# Portfolio formed for _FF_L_VOL_48W_lag_lag
# Portfolio formed for _FF_L_VOL_72W_lag_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_24W_lag_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_48W_lag_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_72W_lag_lag
# Portfolio formed for _FF_M_VOL_lag
# Portfolio formed for _FF_L_VOL_24W_lag_lag
# Portfolio formed for _FF_L_VOL_48W_lag_lag
# Portfolio formed for _FF_L_VOL_72W_lag_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_24W_lag_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_48W_lag_lag
# Portfolio formed for _FF_M_VOL_lag_FF_L_VOL_72W_lag_lag

# %% [markdown]
# ## 2.3 Vol and Other Factors
# ### 2.3.1 With Indicative Fee

# %%
file_list = ['M_VOL', 'FF_M_VOL', 'IndicativeFee' , 'MKTCAP_M']
list_execute = [['M_VOL_lag'], ['FF_M_VOL_lag'], ['IndicativeFee'],
                ['M_VOL_lag', 'IndicativeFee_lag'],
                ['FF_M_VOL_lag', 'IndicativeFee_lag']
                ]

date_list = [datetime.datetime(2004, 1, 1), datetime.datetime(2016, 12, 31)]

for nyse_break in [True, False]:
    form_portfolio.form_portfolio(files=file_list, investable_universe_npy='investable_universe_0221.npy',
                              nyse_permno_xlsx='NYSE PERMNO.xlsx', list_execute=list_execute,
                              nyse_break=nyse_break, startdate=date_list[0], enddate=date_list[1])
# Out:
# Portfolio formed for _FF_M_VOL_lag
# Portfolio formed for _FF_M_VOL_lag

# %% [markdown]
# ### 2.3.2 With Size and Momentum

# %%
file_list = ['M_VOL', 'FF_M_VOL', 'M_RET', 'MKTCAP_M']
list_execute = [['M_VOL_lag'], ['FF_M_VOL_lag'], ['MKTCAP_M_lag'], ['M_RET_lag'],
                ['M_VOL_lag', 'MKTCAP_M_lag'],
                ['FF_M_VOL_lag', 'MKTCAP_M_lag'],
                ['M_VOL_lag', 'M_RET_lag'],
                ['FF_M_VOL_lag', 'M_RET_lag'],
                ]

date_list = [datetime.datetime(1963, 7, 1), datetime.datetime(2016, 12, 31)]

for nyse_break in [True, False]:
    form_portfolio.form_portfolio(files=file_list, investable_universe_npy='investable_universe_0221.npy',
                              nyse_permno_xlsx='NYSE PERMNO.xlsx', list_execute=list_execute,
                              nyse_break=nyse_break, startdate=date_list[0], enddate=date_list[1])
# Out:
# Portfolio formed for _FF_M_VOL_lag
# Portfolio formed for _FF_M_VOL_lag

# %% [markdown]
# ### 2.3.3 With beta

# %%
file_list = ['M_VOL', 'FF_M_VOL', 'MKTCAP_M', 'beta']
list_execute = [['M_VOL_lag'], ['FF_M_VOL_lag'], ['beta_lag'],
                ['M_VOL_lag', 'beta_lag'],
                ['FF_M_VOL_lag', 'beta_lag'],
                ]

date_list = [datetime.datetime(1968, 7, 1), datetime.datetime(2016, 12, 31)]

for nyse_break in [True, False]:
    form_portfolio.form_portfolio(files=file_list, investable_universe_npy='investable_universe_0221.npy',
                              nyse_permno_xlsx='NYSE PERMNO.xlsx', list_execute=list_execute,
                              nyse_break=nyse_break, startdate=date_list[0], enddate=date_list[1])
# Out:
# Portfolio formed for _FF_M_VOL_lag
# Portfolio formed for _FF_M_VOL_lag

# %% [markdown]
# # 3. Post-data Analysis
# ## 3.1 Helper functions

# %%
import scipy.stats
import statsmodels.api as sm

def read_in_signal(name):
    """Read in signal from data prepared"""
    m_data = pd.read_csv(setting.datapath_prepared+name+'.csv')
    m_data['date'] = pd.to_datetime(m_data['date'])
#     m_data_pivot =pd.pivot_table(m_data,columns=['PERMNO'],index=['date'],values=[name])
    m_data_pivot =pd.pivot_table(m_data,columns='PERMNO',index='date',values=name)
    return m_data_pivot


def select_range(m_data, start, end):
    idx = (m_data.index >= start) & (m_data.index < end)
    return m_data.ix[idx]


def analyze_ret(return_series, average_cap_pct, signal_series_list, signal_names):
    n = return_series.shape[1]
    
    amean_ret = return_series.mean()*100
    gmean_ret = pd.Series((scipy.stats.mstats.gmean(np.array(1.0+return_series.values, 
                                                             dtype=float), axis=0)-1.0)*100,
                          index=np.arange(n)+1)
    
    ret_std = np.std(return_series, axis=0)
    
    pf_info_list = []
    if signal_series_list is not None:
        for i in range(len(signal_series_list)):
            pf_info_list.append(signal_series_list[i].mean())
    
    info_summary = [amean_ret, gmean_ret, ret_std, average_cap_pct] + pf_info_list
    info_summary = pd.concat(info_summary, axis=1)
    info_summary.columns = ['Mthly Arithmetic Mean Ret%', 'Mthly Geometric Mean Ret',
                            'Std of Ret', 'Market Cap%']+signal_names
    info_summary = info_summary.round(decimals=3)
    
    return info_summary


def mean_t_stat(tseries, maxlag=20):
    """
    http://statsmodels.sourceforge.net/devel/stats.html
    Return:
        [parameter, Newey West t-stat]
    """
    model = sm.OLS(np.array(tseries, dtype=float), np.ones(len(tseries)))
    result = model.fit(cov_type='HAC',cov_kwds={'maxlags':maxlag})
    nw_t_value = result.tvalues[0]
    # or 
    # nw_t_value = result.params/np.sqrt(sm.stats.sandwich_covariance.cov_hac(result, nlags=maxlag))[0]
    
    return [result.params[0], result.tvalues[0]]
    

def alpha_test(tseries, ff, minusRF, ffalpha=True, j=0, maxlag=12):
    """Calculate the alpha of a series of monthly return
    Args:
        tseries(pd.Series): index is PeriodIndex with freq='M', 
            value is the return (2.3% would be 0.023)
        ff(pd.DataFrame): the fama french 3 factor dataframe
        ffalpha(bool): True-run ff3 regression, False-run CAMP regression
        maxlag(int): the maximum length to calculate the 
            Newey-West standard error
    Return:
        [alpha value, alpha Newey-West t-stat]
    """
    joined_data = pd.concat([tseries, ff], axis=1, join='inner')
    joined_data.columns = ['RET', 'MKT_RF', 'SMB', 'HML', 'RF']
    if minusRF:
        joined_data['ERET'] = joined_data['RET'] - joined_data['RF']
    else:
        joined_data['ERET'] = joined_data['RET']
        
    joined_data['CONST'] = 1.0
    if ffalpha:
        model = sm.OLS(joined_data['ERET'].values, 
                       joined_data[['CONST', 'MKT_RF', 'SMB', 'HML']].values)
    else:
        model = sm.OLS(joined_data['ERET'].values, 
                       joined_data[['CONST', 'MKT_RF']].values)
        
    result = model.fit(cov_type='HAC',cov_kwds={'maxlags':maxlag})
    return [result.params[j], result.tvalues[j]]

# %% [markdown]
# ## 3.2 Main analysis class

# %%
from portfolio_analysis import  review_pf_return, review_pf_signal
import io_tool
import dateutil
import turnover

# %%
class post_data_analysis:
    def __init__(self, pfweight_file, start=None, end=None):
        """Initialize the data needed"""
        self.pfweight_file = pfweight_file
        self.pfweight = io_tool.load_pickle_obj(setting.datapath_pf_weight, self.pfweight_file)
        
        self.cap_pivot=read_in_signal('MKTCAP_M')
        self.return_pivot=read_in_signal('M_RET')
        
        ff_mthly = pd.read_csv('../input/famafrench_mthly.CSV')
        ff_mthly['date'] = pd.to_datetime(ff_mthly['date'], format='%Y%m')
        ff_mthly.set_index('date', inplace=True)
        ff_mthly.columns = ['MKT_RF', 'SMB', 'HML', 'RF']
        ff_mthly = ff_mthly.to_period('M')
        self.ff_mthly = ff_mthly/100.0
        self.prepare_data(start, end)
    
    def prepare_data(self, pf_start=None, pf_end=None):
        if pf_start is None:
            pf_start = np.min(list(self.pfweight.keys()))
        if pf_end is None:
            pf_end = np.max(list(self.pfweight.keys())) + dateutil.relativedelta.relativedelta(months=1)
        
        self.cap_series=review_pf_signal(pf_start,pf_end, self.pfweight, self.cap_pivot)
        self.return_series=review_pf_return(pf_start, pf_end, self.pfweight, self.return_pivot)
        
    def update_pfweight(self, pfweight_file):
        self.pfweight_file = pfweight_file
        self.pfweight = io_tool.load_pickle_obj(setting.datapath_pf_weight, pfweight_file)
        self.prepare_data()
        
    def get_summary1(self, start, end):
        
        m_cap_series = select_range(self.cap_series, start, end)
        m_return_series = select_range(self.return_series, start, end)
        
        average_cap_pct = m_cap_series.mean()/np.sum(m_cap_series.mean())
        
        num_port = m_return_series.shape[1]
        # summary table 
        table1 = analyze_ret(m_return_series, average_cap_pct, [m_cap_series], ['Mkt Cap Mean'])
        # long short port mean ret
        table2 = pd.DataFrame(mean_t_stat(m_return_series[num_port].values-m_return_series[1].values), 
                              index=['mean', 't-stat'], columns=[str(num_port)+'-1'])
        
        # alpha table
        alpha_results = np.zeros((num_port+1, 4))
        for i in range(num_port):
            alpha_results[i,:2] = alpha_test(m_return_series[i+1], self.ff_mthly, minusRF=True, ffalpha=False)
            alpha_results[i,2:] = alpha_test(m_return_series[i+1], self.ff_mthly, minusRF=True, ffalpha=True)

        alpha_results[-1, :2] = alpha_test(m_return_series[num_port]-m_return_series[1],
                                           self.ff_mthly, minusRF=False, ffalpha=False)
        alpha_results[-1, 2:] = alpha_test(m_return_series[num_port]-m_return_series[1],
                                           self.ff_mthly, minusRF=False, ffalpha=True)
        
        alpha_results[:, (0, 2)] = alpha_results[:, (0, 2)] * 100
        
        table3 = pd.DataFrame(alpha_results, index=list(np.arange(1, num_port+1))+[str(num_port)+'-1'], 
                                     columns=['CAPM alpha%', 'CAPM t-stat', 'FF3 alpha%', 'FF3 t-stat'])
        
        self.table = [table1, table2, table3]
    
    def get_summary2(self,name1, name2, start, end):
        m_cap_series = select_range(self.cap_series, start, end)
        m_return_series = select_range(self.return_series, start, end)
        num_port = m_return_series.shape[1]
        # this summary is designed for 25 portfolios
        assert num_port == 25
        
        alpha_coef = np.zeros((6, 6))
        alpha_t = np.zeros((6, 6))
        # loop throgh the first signal group
        for i in range(5):
            # loop throgh the second signal group
            for j in range(5):
                alpha_coef[j, i], alpha_t[j, i] = alpha_test(m_return_series[5*i+j+1],
                                                                          self.ff_mthly, minusRF=True, ffalpha=True)
            # given the first signal, second signal 5-1
            alpha_coef[5, i], alpha_t[5, i] = alpha_test(m_return_series[5*i+5]-m_return_series[5*i+1],
                                                        self.ff_mthly, minusRF=False, ffalpha=True)
        
        # given the second signal, the first signal 5-1
        for j in range(5):
            alpha_coef[j, 5], alpha_t[j, 5] = alpha_test(m_return_series[20+j+1]-m_return_series[j+1],
                                                        self.ff_mthly, minusRF=False, ffalpha=True)
            
            
        column_name = [ name1+str(x+1) for x in range(5)] + [name1+'(5-1)']
        index_name = [ name2+str(x+1) for x in range(5)] + [name2+'(5-1)']
        
        alpha_coef = pd.DataFrame(alpha_coef*100, index=index_name, columns=column_name)
        alpha_coef.index.name = 'Fama French alpha%'
        alpha_t = pd.DataFrame(alpha_t, index=index_name, columns=column_name)
        alpha_t.index.name = 'alpha t-stat'
        
        self.table2 = [alpha_coef, alpha_t]

# %% [markdown]
# ## 3.3 Helper functions for aggregating output

# %%
# Helper functions for aggregate output

def wrapper_25_to_table(data):
    table = np.zeros((5, 5))
    for i in range(5):
        for j in range(5):
            table[j, i] = data[5*i+j]
    return table
    
def get_stk_number(pfweight, start, end):
    current = start
    num_port = len(pfweight[current])
    record_list = []
    while current < end:
        current_weight = pfweight[current]
        temp = np.zeros(num_port)
        for i in range(num_port):
            temp[i] = current_weight[i].shape[0]            
        
        record_list.append(temp)
        current += dateutil.relativedelta.relativedelta(months=1)
    return np.array(record_list)

# %% [markdown]
# ## 3.4 Output Aggregation and Export to Excel

# %%
import xlsxwriter

def aggregate_output(analysis_robot, name_list, m_writer, start, end, nysebreak=False):
    # pre analysis
    if len(name_list) == 1:
        sheetname = name_list[0]+'_'+str(nysebreak)
    else:
        sheetname = name_list[0][:12]+'_'+name_list[1][:12]+'_'+str(nysebreak)
    
#     print('..write to'+sheetname)
    analysis_robot.get_summary1(start, end);
    
    # excel writer initialize
    workbook  = m_writer.book
    
    # analysis
    stk_num_record = get_stk_number(analysis_robot.pfweight, start, end).mean(axis=0)
    port_turnover = turnover.Turnover_rate(analysis_robot.pfweight, start, end).mean(axis=0).values
    
    if len(name_list) == 1:
        group_name = [name_list[0] + str(x+1) for x in range(5)]
        stk_num_df = pd.DataFrame(stk_num_record, index=group_name).round(2)
        stk_num_df.index.name = 'Average Stk Number'
        
        port_turnover_df = pd.DataFrame(port_turnover, index=group_name).round(2)
        port_turnover_df.index.name = 'Pct Stk Change'
        
        stk_num_df.to_excel(m_writer, sheet_name=sheetname)
        port_turnover_df.to_excel(m_writer, sheet_name=sheetname, startcol= stk_num_df.shape[1]+2)
        
        row_record = stk_num_df.shape[0] + 2
        analysis_robot.table[0].to_excel(m_writer, sheet_name=sheetname,
                                         startrow=row_record)
        (analysis_robot.table[2].round(2)).to_excel(m_writer, sheet_name=sheetname,
                                         startrow=row_record, 
                                         startcol=analysis_robot.table[0].shape[1]+2)
        row_record = row_record + analysis_robot.table[0].shape[0] + 2
        analysis_robot.table[1].to_excel(m_writer, sheet_name=sheetname, startrow=row_record)
        worksheet = m_writer.sheets[sheetname]
    else:
        column_name = [name_list[0]+str(x+1) for x in range(5)]
        index_name = [name_list[1]+str(x+1) for x in range(5)]
        
        analysis_robot.get_summary2(name1=name_list[0], name2=name_list[1], start=start, end=end);
        stk_num_df = pd.DataFrame(wrapper_25_to_table(stk_num_record),
                                  index=index_name, columns=column_name).round(2)
        stk_num_df.index.name = 'Average Stk Number'
        
        port_turnover_df = pd.DataFrame(wrapper_25_to_table(port_turnover),
                                  index=index_name, columns=column_name).round(2)
        port_turnover_df.index.name = 'Pct Stk Change'
        
        table_to_write = [stk_num_df]
        
        # wrap table one into 5x5 table
        for i in range(analysis_robot.table[0].shape[1]):
            temp_df = pd.DataFrame(wrapper_25_to_table(analysis_robot.table[0].iloc[:,i].values), 
                        index=index_name, columns=column_name)
            temp_df.index.name = analysis_robot.table[0].columns[i]
            table_to_write.append(temp_df)
        
        # add alpha table
        table_to_write = table_to_write + analysis_robot.table2
        table_to_write.append(port_turnover_df)
        
        row_record = 1
        col_record = 0
        row_record_list = [row_record]
        for i in range(len(table_to_write)):
            item = table_to_write[i].round(3)
            item.to_excel(m_writer, sheet_name=sheetname, 
                                       startrow=row_record, startcol=col_record)
            if i%2==0:
                col_record= 8 #item.shape[1] + 4
            else:
                col_record = 0
                row_record = row_record+item.shape[0]+2
                row_record_list.append(row_record)
        row_record_list.append(row_record+item.shape[0]+1)
    
        worksheet = m_writer.sheets[sheetname]
        for i in range(1, len(row_record_list)):
            worksheet.conditional_format('A'+str(row_record_list[i-1])+':G'+str(row_record_list[i]),
                                                 {'type': '3_color_scale'})
            worksheet.conditional_format('I'+str(row_record_list[i-1])+':P'+str(row_record_list[i]),
                                                 {'type': '3_color_scale'})
    
    # Widen the first column to make the text clearer.
    worksheet.set_column('A:Z', 12)
    
def wrapper_analysis_write(outputname, inputrange, list_execute, startdate, enddate, nyse_break_list):
    """
    :outputname(str): the name of the excel to save data
    :inputrange(str): the string of range of dates, e.g. '2010-01-2015-06'
    :list_execute(list of list of str): the list of the signal names that we examine (at most two signals in one list)
        e.g. [['M_VOL_lag'], ['M_VOL_lag', 'L_VOL_12M_lag']]
    :startdate(datetime.datetime): the date we use to start backtest
    :enddate(datetime.datetime): the date we end backtest
    :nyse_break_list(list of bool): [True, False] or [True] to set whether we use NYSE breakpoints
    """
    writer = pd.ExcelWriter('../output/'+outputname, engine='xlsxwriter')
    workbook = writer.book
    worksheet = workbook.add_worksheet()

    date_format = workbook.add_format({'num_format': 'mm/dd/yy',
                                          'align': 'left'})
    worksheet.write_datetime(1, 1, startdate, date_format)
    worksheet.write_datetime(2, 2, enddate, date_format)

    for nyse_break in nyse_break_list:
        for i in range(len(list_execute)):
            if len(list_execute[i])==1:
                file_name = 'pfweight_'+list_execute[i][0]+'_'+str(nyse_break)+inputrange
            else:
                file_name = 'pfweight_'+list_execute[i][0]+'_'+list_execute[i][1]+'_'+str(nyse_break)+inputrange
            print('Analyze and aggregate: ',file_name)
            analysis_robot=post_data_analysis(file_name, startdate, enddate)
            names = [x[:-4] for x in list_execute[i]]
            aggregate_output(analysis_robot, names, writer, startdate, enddate, nyse_break)
            
    writer.save()

# %% [markdown]
# # 4. Output Execution
# ## 4.1 Vol from Monthly
# ### 4.1.1 Total Vol

# %%
list_execute = [['M_VOL_lag'], 
                ['L_VOL_12M_lag_lag'], ['L_VOL_18M_lag_lag'], ['L_VOL_24M_lag_lag'], ['L_VOL_36M_lag_lag'],
                ['M_VOL_lag', 'L_VOL_12M_lag_lag'],
                ['M_VOL_lag', 'L_VOL_18M_lag_lag'],
                ['M_VOL_lag', 'L_VOL_24M_lag_lag'],
                ['M_VOL_lag', 'L_VOL_36M_lag_lag']
                ]

startdate = datetime.datetime(1965, 2, 1)
enddate = datetime.datetime(2016, 12, 31)
nyse_break_list = [True, False]
wrapper_analysis_write('analysis_mthly_tot0303.xlsx','1965-02-2016-12', list_execute, startdate, enddate, nyse_break_list)
# Out:
# Analyze and aggregate:  pfweight_M_VOL_lag_True1965-02-2016-12
# Analyze and aggregate:  pfweight_L_VOL_12M_lag_lag_True1965-02-2016-12
# Analyze and aggregate:  pfweight_L_VOL_18M_lag_lag_True1965-02-2016-12
# Analyze and aggregate:  pfweight_L_VOL_24M_lag_lag_True1965-02-2016-12
# Analyze and aggregate:  pfweight_L_VOL_36M_lag_lag_True1965-02-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_12M_lag_lag_True1965-02-2016-12
# skipped1965-05-01 00:00:00on 4th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-09-01 00:00:00on 9th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 9th portfolio
# skipped1966-01-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 9th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-11-01 00:00:00on 9th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 9th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 9th portfolio
# skipped1967-03-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 9th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 9th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 9th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1968-04-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 9th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1969-06-01 00:00:00on 4th portfolio
# skipped1969-07-01 00:00:00on 4th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 9th portfolio
# skipped1971-06-01 00:00:00on 4th portfolio
# skipped1971-08-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 9th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-03-01 00:00:00on 4th portfolio
# skipped1972-06-01 00:00:00on 9th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-08-01 00:00:00on 3th portfolio
# skipped1991-04-01 00:00:00on 4th portfolio
# skipped1992-07-01 00:00:00on 4th portfolio
# skipped1995-04-01 00:00:00on 9th portfolio
# skipped1965-05-01 00:00:00on 4th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-09-01 00:00:00on 9th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 9th portfolio
# skipped1966-01-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 9th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-11-01 00:00:00on 9th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 9th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 9th portfolio
# skipped1967-03-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 9th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 9th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 9th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1968-04-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 9th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1969-06-01 00:00:00on 4th portfolio
# skipped1969-07-01 00:00:00on 4th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 9th portfolio
# skipped1971-06-01 00:00:00on 4th portfolio
# skipped1971-08-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 9th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-03-01 00:00:00on 4th portfolio
# skipped1972-06-01 00:00:00on 9th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-08-01 00:00:00on 3th portfolio
# skipped1991-04-01 00:00:00on 4th portfolio
# skipped1992-07-01 00:00:00on 4th portfolio
# skipped1995-04-01 00:00:00on 9th portfolio
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_18M_lag_lag_True1965-02-2016-12
# skipped1965-08-01 00:00:00on 9th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-09-01 00:00:00on 9th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 9th portfolio
# skipped1965-11-01 00:00:00on 9th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 9th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 9th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 9th portfolio
# skipped1967-03-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 3th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 9th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 9th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-02-01 00:00:00on 9th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1968-04-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 4th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1968-07-01 00:00:00on 4th portfolio
# skipped1968-08-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 4th portfolio
# skipped1969-01-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 9th portfolio
# skipped1969-07-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-04-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 9th portfolio
# skipped1971-06-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-03-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1972-08-01 00:00:00on 4th portfolio
# skipped1972-11-01 00:00:00on 4th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-08-01 00:00:00on 2th portfolio
# skipped1991-04-01 00:00:00on 4th portfolio
# skipped1992-07-01 00:00:00on 4th portfolio
# skipped1994-02-01 00:00:00on 4th portfolio
# skipped1994-04-01 00:00:00on 4th portfolio
# skipped1996-08-01 00:00:00on 4th portfolio
# skipped1965-08-01 00:00:00on 9th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-09-01 00:00:00on 9th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 9th portfolio
# skipped1965-11-01 00:00:00on 9th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 9th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 9th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 9th portfolio
# skipped1967-03-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 3th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 9th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 9th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-02-01 00:00:00on 9th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1968-04-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 4th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1968-07-01 00:00:00on 4th portfolio
# skipped1968-08-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 4th portfolio
# skipped1969-01-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 9th portfolio
# skipped1969-07-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-04-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 9th portfolio
# skipped1971-06-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-03-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1972-08-01 00:00:00on 4th portfolio
# skipped1972-11-01 00:00:00on 4th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-08-01 00:00:00on 2th portfolio
# skipped1991-04-01 00:00:00on 4th portfolio
# skipped1992-07-01 00:00:00on 4th portfolio
# skipped1994-02-01 00:00:00on 4th portfolio
# skipped1994-04-01 00:00:00on 4th portfolio
# skipped1996-08-01 00:00:00on 4th portfolio
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_24M_lag_lag_True1965-02-2016-12
# skipped1965-05-01 00:00:00on 9th portfolio
# skipped1965-08-01 00:00:00on 9th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-09-01 00:00:00on 9th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 9th portfolio
# skipped1965-11-01 00:00:00on 9th portfolio
# skipped1965-12-01 00:00:00on 9th portfolio
# skipped1966-01-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 9th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 9th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 9th portfolio
# skipped1967-03-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 3th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 9th portfolio
# skipped1967-09-01 00:00:00on 9th portfolio
# skipped1967-10-01 00:00:00on 3th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 9th portfolio
# skipped1968-04-01 00:00:00on 3th portfolio
# skipped1968-04-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 4th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1968-07-01 00:00:00on 4th portfolio
# skipped1968-08-01 00:00:00on 4th portfolio
# skipped1968-09-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 4th portfolio
# skipped1969-02-01 00:00:00on 9th portfolio
# skipped1969-03-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 9th portfolio
# skipped1969-06-01 00:00:00on 4th portfolio
# skipped1969-07-01 00:00:00on 4th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1969-09-01 00:00:00on 4th portfolio
# skipped1969-11-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-04-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-11-01 00:00:00on 4th portfolio
# skipped1971-01-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 9th portfolio
# skipped1971-08-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 9th portfolio
# skipped1971-11-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-03-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1972-08-01 00:00:00on 4th portfolio
# skipped1972-11-01 00:00:00on 4th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1991-04-01 00:00:00on 4th portfolio
# skipped1992-07-01 00:00:00on 4th portfolio
# skipped1992-12-01 00:00:00on 4th portfolio
# skipped1993-01-01 00:00:00on 4th portfolio
# skipped1995-12-01 00:00:00on 4th portfolio
# skipped1996-11-01 00:00:00on 4th portfolio
# skipped1965-05-01 00:00:00on 9th portfolio
# skipped1965-08-01 00:00:00on 9th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-09-01 00:00:00on 9th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 9th portfolio
# skipped1965-11-01 00:00:00on 9th portfolio
# skipped1965-12-01 00:00:00on 9th portfolio
# skipped1966-01-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 9th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 9th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 9th portfolio
# skipped1967-03-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 3th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 9th portfolio
# skipped1967-09-01 00:00:00on 9th portfolio
# skipped1967-10-01 00:00:00on 3th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 9th portfolio
# skipped1968-04-01 00:00:00on 3th portfolio
# skipped1968-04-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 4th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1968-07-01 00:00:00on 4th portfolio
# skipped1968-08-01 00:00:00on 4th portfolio
# skipped1968-09-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 4th portfolio
# skipped1969-02-01 00:00:00on 9th portfolio
# skipped1969-03-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 9th portfolio
# skipped1969-06-01 00:00:00on 4th portfolio
# skipped1969-07-01 00:00:00on 4th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1969-09-01 00:00:00on 4th portfolio
# skipped1969-11-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-04-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-11-01 00:00:00on 4th portfolio
# skipped1971-01-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 9th portfolio
# skipped1971-08-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 9th portfolio
# skipped1971-11-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-03-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1972-08-01 00:00:00on 4th portfolio
# skipped1972-11-01 00:00:00on 4th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1991-04-01 00:00:00on 4th portfolio
# skipped1992-07-01 00:00:00on 4th portfolio
# skipped1992-12-01 00:00:00on 4th portfolio
# skipped1993-01-01 00:00:00on 4th portfolio
# skipped1995-12-01 00:00:00on 4th portfolio
# skipped1996-11-01 00:00:00on 4th portfolio
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_36M_lag_lag_True1965-02-2016-12
# skipped1965-04-01 00:00:00on 4th portfolio
# skipped1965-08-01 00:00:00on 9th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-09-01 00:00:00on 9th portfolio
# skipped1965-10-01 00:00:00on 9th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1965-12-01 00:00:00on 9th portfolio
# skipped1966-02-01 00:00:00on 3th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 9th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 9th portfolio
# skipped1966-08-01 00:00:00on 4th portfolio
# skipped1966-10-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 9th portfolio
# skipped1967-03-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 9th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 9th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 9th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 9th portfolio
# skipped1968-04-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 4th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1968-09-01 00:00:00on 4th portfolio
# skipped1968-09-01 00:00:00on 9th portfolio
# skipped1968-11-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 4th portfolio
# skipped1969-02-01 00:00:00on 9th portfolio
# skipped1969-03-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1969-06-01 00:00:00on 4th portfolio
# skipped1969-07-01 00:00:00on 4th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1969-10-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-02-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-11-01 00:00:00on 4th portfolio
# skipped1971-01-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 9th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-04-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 9th portfolio
# skipped1971-08-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 9th portfolio
# skipped1972-04-01 00:00:00on 9th portfolio
# skipped1972-05-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1972-08-01 00:00:00on 4th portfolio
# skipped1972-11-01 00:00:00on 4th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-04-01 00:00:00on 3th portfolio
# skipped1974-02-01 00:00:00on 4th portfolio
# skipped1974-03-01 00:00:00on 4th portfolio
# skipped1991-04-01 00:00:00on 4th portfolio
# skipped1996-11-01 00:00:00on 4th portfolio
# skipped1965-04-01 00:00:00on 4th portfolio
# skipped1965-08-01 00:00:00on 9th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-09-01 00:00:00on 9th portfolio
# skipped1965-10-01 00:00:00on 9th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1965-12-01 00:00:00on 9th portfolio
# skipped1966-02-01 00:00:00on 3th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 9th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 9th portfolio
# skipped1966-08-01 00:00:00on 4th portfolio
# skipped1966-10-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 9th portfolio
# skipped1967-03-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 9th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 9th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 9th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 9th portfolio
# skipped1968-04-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 4th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1968-09-01 00:00:00on 4th portfolio
# skipped1968-09-01 00:00:00on 9th portfolio
# skipped1968-11-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 4th portfolio
# skipped1969-02-01 00:00:00on 9th portfolio
# skipped1969-03-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1969-06-01 00:00:00on 4th portfolio
# skipped1969-07-01 00:00:00on 4th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1969-10-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-02-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-11-01 00:00:00on 4th portfolio
# skipped1971-01-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 9th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-04-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 9th portfolio
# skipped1971-08-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 9th portfolio
# skipped1972-04-01 00:00:00on 9th portfolio
# skipped1972-05-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1972-08-01 00:00:00on 4th portfolio
# skipped1972-11-01 00:00:00on 4th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-04-01 00:00:00on 3th portfolio
# skipped1974-02-01 00:00:00on 4th portfolio
# skipped1974-03-01 00:00:00on 4th portfolio
# skipped1991-04-01 00:00:00on 4th portfolio
# skipped1996-11-01 00:00:00on 4th portfolio
# Analyze and aggregate:  pfweight_M_VOL_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_L_VOL_12M_lag_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_L_VOL_18M_lag_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_L_VOL_24M_lag_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_L_VOL_36M_lag_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_12M_lag_lag_False1965-02-2016-12
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 20th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 20th portfolio
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_18M_lag_lag_False1965-02-2016-12
# skipped1965-03-01 00:00:00on 20th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 20th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 20th portfolio
# skipped1973-06-01 00:00:00on 20th portfolio
# skipped1973-08-01 00:00:00on 20th portfolio
# skipped1965-03-01 00:00:00on 20th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 20th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 20th portfolio
# skipped1973-06-01 00:00:00on 20th portfolio
# skipped1973-08-01 00:00:00on 20th portfolio
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_24M_lag_lag_False1965-02-2016-12
# skipped1965-03-01 00:00:00on 20th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 20th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 20th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 20th portfolio
# skipped1970-12-01 00:00:00on 20th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 20th portfolio
# skipped1973-06-01 00:00:00on 20th portfolio
# skipped1973-09-01 00:00:00on 20th portfolio
# skipped1973-12-01 00:00:00on 20th portfolio
# skipped1965-03-01 00:00:00on 20th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 20th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 20th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 20th portfolio
# skipped1970-12-01 00:00:00on 20th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 20th portfolio
# skipped1973-06-01 00:00:00on 20th portfolio
# skipped1973-09-01 00:00:00on 20th portfolio
# skipped1973-12-01 00:00:00on 20th portfolio
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_36M_lag_lag_False1965-02-2016-12
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 20th portfolio
# skipped1966-08-01 00:00:00on 4th portfolio
# skipped1966-10-01 00:00:00on 4th portfolio
# skipped1966-10-01 00:00:00on 20th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 20th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1968-09-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 20th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 20th portfolio
# skipped1972-01-01 00:00:00on 20th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 20th portfolio
# skipped1972-09-01 00:00:00on 20th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 20th portfolio
# skipped1973-08-01 00:00:00on 20th portfolio
# skipped1973-09-01 00:00:00on 20th portfolio
# skipped1973-12-01 00:00:00on 20th portfolio
# skipped1974-02-01 00:00:00on 20th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 20th portfolio
# skipped1966-08-01 00:00:00on 4th portfolio
# skipped1966-10-01 00:00:00on 4th portfolio
# skipped1966-10-01 00:00:00on 20th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 20th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1968-09-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 20th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 20th portfolio
# skipped1972-01-01 00:00:00on 20th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 20th portfolio
# skipped1972-09-01 00:00:00on 20th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 20th portfolio
# skipped1973-08-01 00:00:00on 20th portfolio
# skipped1973-09-01 00:00:00on 20th portfolio
# skipped1973-12-01 00:00:00on 20th portfolio
# skipped1974-02-01 00:00:00on 20th portfolio

# %%
list_execute = [['M_VOL_lag'], 
#                 ['L_VOL_12M_lag_lag'], ['L_VOL_18M_lag_lag'], 
                ['L_VOL_24M_lag_lag'], 
#                 ['L_VOL_36M_lag_lag'],
#                 ['M_VOL_lag', 'L_VOL_12M_lag_lag'],
#                 ['M_VOL_lag', 'L_VOL_18M_lag_lag'],
                ['M_VOL_lag', 'L_VOL_24M_lag_lag'],
#                 ['M_VOL_lag', 'L_VOL_36M_lag_lag']
                ]

startdate = datetime.datetime(2004, 1, 1)
enddate = datetime.datetime(2016, 12, 31)
nyse_break_list = [False]
wrapper_analysis_write('analysis_mthly_tot_aft2004.xlsx','1965-02-2016-12', list_execute, startdate, enddate, nyse_break_list)
# Out:
# Analyze and aggregate:  pfweight_M_VOL_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_L_VOL_24M_lag_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_24M_lag_lag_False1965-02-2016-12

# %%
list_execute = [['M_VOL_lag'], 
#                 ['L_VOL_12M_lag_lag'], ['L_VOL_18M_lag_lag'], 
                ['L_VOL_24M_lag_lag'], 
#                 ['L_VOL_36M_lag_lag'],
#                 ['M_VOL_lag', 'L_VOL_12M_lag_lag'],
#                 ['M_VOL_lag', 'L_VOL_18M_lag_lag'],
                ['M_VOL_lag', 'L_VOL_24M_lag_lag'],
#                 ['M_VOL_lag', 'L_VOL_36M_lag_lag']
                ]

# startdate = datetime.datetime(2004, 1, 1)
# enddate = datetime.datetime(2016, 12, 31)
# wrapper_analysis_write('analysis_mthly_tot_aft2004.xlsx','1965-02-2016-12', list_execute, startdate, enddate, nyse_break_list)

startdate = datetime.datetime(2001, 1, 1)
enddate = datetime.datetime(2016, 12, 31)
nyse_break_list = [False]
wrapper_analysis_write('analysis_mthly_tot_aft2001.xlsx','1965-02-2016-12', list_execute, startdate, enddate, nyse_break_list)

startdate = datetime.datetime(1965, 2, 1)
enddate = datetime.datetime(2000, 12, 31)
nyse_break_list = [False]
wrapper_analysis_write('analysis_mthly_tot_bef2001.xlsx','1965-02-2016-12', list_execute, startdate, enddate, nyse_break_list)
# Out:
# Analyze and aggregate:  pfweight_M_VOL_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_L_VOL_24M_lag_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_24M_lag_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_L_VOL_24M_lag_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_24M_lag_lag_False1965-02-2016-12
# skipped1965-04-01 00:00:00on 4th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 20th portfolio
# skipped1966-06-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 20th portfolio
# skipped1966-08-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1969-09-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 20th portfolio
# skipped1973-09-01 00:00:00on 20th portfolio
# skipped1965-04-01 00:00:00on 4th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 20th portfolio
# skipped1966-06-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 20th portfolio
# skipped1966-08-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1969-09-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 20th portfolio
# skipped1973-09-01 00:00:00on 20th portfolio

# %% [markdown]
# ### 4.1.2 Idio Vol

# %%
list_execute = [['FF_M_VOL_lag'], 
                ['FF_L_VOL_12M_lag_lag'], ['FF_L_VOL_18M_lag_lag'], ['FF_L_VOL_24M_lag_lag'], ['FF_L_VOL_36M_lag_lag'],
                ['FF_M_VOL_lag', 'FF_L_VOL_12M_lag_lag'],
                ['FF_M_VOL_lag', 'FF_L_VOL_18M_lag_lag'],
                ['FF_M_VOL_lag', 'FF_L_VOL_24M_lag_lag'],
                ['FF_M_VOL_lag', 'FF_L_VOL_36M_lag_lag']
                ]

startdate = datetime.datetime(1965, 2, 1)
enddate = datetime.datetime(2016, 12, 31)
nyse_break_list = [True, False]
wrapper_analysis_write('analysis_mthly_idio.xlsx','1965-02-2016-12', list_execute, startdate, enddate, nyse_break_list)

# %%
list_execute = [['FF_M_VOL_lag'], 
#                 ['FF_L_VOL_12M_lag_lag'], ['FF_L_VOL_18M_lag_lag'], 
                ['FF_L_VOL_24M_lag_lag'], 
#                 ['FF_L_VOL_36M_lag_lag'],
#                 ['FF_M_VOL_lag', 'FF_L_VOL_12M_lag_lag'],
#                 ['FF_M_VOL_lag', 'FF_L_VOL_18M_lag_lag'],
                ['FF_M_VOL_lag', 'FF_L_VOL_24M_lag_lag'],
#                 ['FF_M_VOL_lag', 'FF_L_VOL_36M_lag_lag']
                ]

# startdate = datetime.datetime(2004, 1, 1)
# enddate = datetime.datetime(2016, 12, 31)
# nyse_break_list = [False]
# wrapper_analysis_write('analysis_mthly_idio_aft2004.xlsx','1965-02-2016-12', list_execute, startdate, enddate, nyse_break_list)

startdate = datetime.datetime(2001, 1, 1)
enddate = datetime.datetime(2016, 12, 31)
nyse_break_list = [False]
wrapper_analysis_write('analysis_mthly_idio_aft2001.xlsx','1965-02-2016-12', list_execute, startdate, enddate, nyse_break_list)

startdate = datetime.datetime(1965, 2, 1)
enddate = datetime.datetime(2000, 12, 31)
nyse_break_list = [False]
wrapper_analysis_write('analysis_mthly_idio_bef2001.xlsx','1965-02-2016-12', list_execute, startdate, enddate, nyse_break_list)
# Out:
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_FF_L_VOL_24M_lag_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_FF_L_VOL_24M_lag_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_FF_L_VOL_24M_lag_lag_False1965-02-2016-12
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_FF_L_VOL_24M_lag_lag_False1965-02-2016-12
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio

# %% [markdown]
# ## 4.2 Vol from Weekly
# ### 4.2.1 Total Vol

# %%
list_execute = [['M_VOL_lag'], 
                ['L_VOL_24W_lag_lag'], ['L_VOL_48W_lag_lag'], ['L_VOL_72W_lag_lag'], 
                ['M_VOL_lag', 'L_VOL_24W_lag_lag'],
                ['M_VOL_lag', 'L_VOL_48W_lag_lag'],
                ['M_VOL_lag', 'L_VOL_72W_lag_lag']]

startdate = datetime.datetime(1965, 2, 1)
enddate = datetime.datetime(2016, 12, 31)
nyse_break_list = [True, False]
# We input data from 1963-07 to 2016-12, but calculate the results using 1965-02 to 2016-12
wrapper_analysis_write('analysis_weekly_tot0303.xlsx','1963-07-2016-12', list_execute, startdate, enddate, nyse_break_list)
# Out:
# Analyze and aggregate:  pfweight_M_VOL_lag_True1963-07-2016-12
# review_pf_signal done
# review_pf_return done
# ..write toM_VOL_True
# Analyze and aggregate:  pfweight_L_VOL_24W_lag_lag_True1963-07-2016-12
# review_pf_signal done
# review_pf_return done
# ..write toL_VOL_24W_lag_True
# Analyze and aggregate:  pfweight_L_VOL_48W_lag_lag_True1963-07-2016-12
# review_pf_signal done
# review_pf_return done
# ..write toL_VOL_48W_lag_True
# Analyze and aggregate:  pfweight_L_VOL_72W_lag_lag_True1963-07-2016-12
# review_pf_signal done
# review_pf_return done
# ..write toL_VOL_72W_lag_True
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_24W_lag_lag_True1963-07-2016-12
# skipped1963-11-01 00:00:00on 9th portfolio
# skipped1964-01-01 00:00:00on 4th portfolio
# skipped1964-02-01 00:00:00on 4th portfolio
# skipped1964-03-01 00:00:00on 4th portfolio
# skipped1964-04-01 00:00:00on 4th portfolio
# skipped1964-05-01 00:00:00on 4th portfolio
# skipped1964-09-01 00:00:00on 9th portfolio
# skipped1964-10-01 00:00:00on 4th portfolio
# skipped1964-12-01 00:00:00on 4th portfolio
# skipped1965-01-01 00:00:00on 9th portfolio
# skipped1965-04-01 00:00:00on 9th portfolio
# skipped1965-05-01 00:00:00on 4th portfolio
# skipped1965-06-01 00:00:00on 4th portfolio
# skipped1965-08-01 00:00:00on 4th portfolio
# skipped1965-08-01 00:00:00on 9th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1966-01-01 00:00:00on 4th portfolio
# skipped1966-01-01 00:00:00on 9th portfolio
# skipped1966-02-01 00:00:00on 9th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 9th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 9th portfolio
# skipped1967-02-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 9th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 9th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1969-02-01 00:00:00on 9th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1969-09-01 00:00:00on 4th portfolio
# skipped1969-10-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 9th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 9th portfolio
# skipped1971-01-01 00:00:00on 3th portfolio
# skipped1971-01-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-04-01 00:00:00on 9th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-06-01 00:00:00on 4th portfolio
# skipped1971-07-01 00:00:00on 4th portfolio
# skipped1971-07-01 00:00:00on 9th portfolio
# skipped1971-08-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-04-01 00:00:00on 3th portfolio
# skipped1972-05-01 00:00:00on 9th portfolio
# skipped1972-06-01 00:00:00on 9th portfolio
# skipped1973-06-01 00:00:00on 4th portfolio
# skipped1995-05-01 00:00:00on 9th portfolio
# review_pf_signal done
# skipped1963-11-01 00:00:00on 9th portfolio
# skipped1964-01-01 00:00:00on 4th portfolio
# skipped1964-02-01 00:00:00on 4th portfolio
# skipped1964-03-01 00:00:00on 4th portfolio
# skipped1964-04-01 00:00:00on 4th portfolio
# skipped1964-05-01 00:00:00on 4th portfolio
# skipped1964-09-01 00:00:00on 9th portfolio
# skipped1964-10-01 00:00:00on 4th portfolio
# skipped1964-12-01 00:00:00on 4th portfolio
# skipped1965-01-01 00:00:00on 9th portfolio
# skipped1965-04-01 00:00:00on 9th portfolio
# skipped1965-05-01 00:00:00on 4th portfolio
# skipped1965-06-01 00:00:00on 4th portfolio
# skipped1965-08-01 00:00:00on 4th portfolio
# skipped1965-08-01 00:00:00on 9th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1966-01-01 00:00:00on 4th portfolio
# skipped1966-01-01 00:00:00on 9th portfolio
# skipped1966-02-01 00:00:00on 9th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 9th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 9th portfolio
# skipped1967-02-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 9th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 9th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1969-02-01 00:00:00on 9th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1969-09-01 00:00:00on 4th portfolio
# skipped1969-10-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 9th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 9th portfolio
# skipped1971-01-01 00:00:00on 3th portfolio
# skipped1971-01-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-04-01 00:00:00on 9th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-06-01 00:00:00on 4th portfolio
# skipped1971-07-01 00:00:00on 4th portfolio
# skipped1971-07-01 00:00:00on 9th portfolio
# skipped1971-08-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-04-01 00:00:00on 3th portfolio
# skipped1972-05-01 00:00:00on 9th portfolio
# skipped1972-06-01 00:00:00on 9th portfolio
# skipped1973-06-01 00:00:00on 4th portfolio
# skipped1995-05-01 00:00:00on 9th portfolio
# review_pf_return done
# ..write toM_VOL_L_VOL_24_True
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_48W_lag_lag_True1963-07-2016-12
# skipped1963-09-01 00:00:00on 4th portfolio
# skipped1964-02-01 00:00:00on 4th portfolio
# skipped1964-03-01 00:00:00on 4th portfolio
# skipped1964-04-01 00:00:00on 4th portfolio
# skipped1964-05-01 00:00:00on 4th portfolio
# skipped1964-05-01 00:00:00on 9th portfolio
# skipped1964-08-01 00:00:00on 9th portfolio
# skipped1965-04-01 00:00:00on 4th portfolio
# skipped1965-04-01 00:00:00on 9th portfolio
# skipped1965-05-01 00:00:00on 4th portfolio
# skipped1965-06-01 00:00:00on 4th portfolio
# skipped1965-08-01 00:00:00on 9th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 9th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1965-11-01 00:00:00on 9th portfolio
# skipped1965-12-01 00:00:00on 9th portfolio
# skipped1966-01-01 00:00:00on 9th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 9th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-03-01 00:00:00on 9th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 9th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 14th portfolio
# skipped1966-06-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 9th portfolio
# skipped1966-08-01 00:00:00on 4th portfolio
# skipped1966-10-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 9th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 9th portfolio
# skipped1967-02-01 00:00:00on 4th portfolio
# skipped1967-03-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 9th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 9th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1968-04-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 4th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1968-08-01 00:00:00on 4th portfolio
# skipped1968-09-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 3th portfolio
# skipped1968-12-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 9th portfolio
# skipped1969-05-01 00:00:00on 4th portfolio
# skipped1969-07-01 00:00:00on 4th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1969-09-01 00:00:00on 4th portfolio
# skipped1969-10-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-04-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 3th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 3th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 9th portfolio
# skipped1971-01-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 9th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-04-01 00:00:00on 3th portfolio
# skipped1971-04-01 00:00:00on 9th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 9th portfolio
# skipped1971-06-01 00:00:00on 4th portfolio
# skipped1971-08-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 9th portfolio
# skipped1972-02-01 00:00:00on 3th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-05-01 00:00:00on 3th portfolio
# skipped1972-05-01 00:00:00on 9th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-04-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 4th portfolio
# skipped1994-02-01 00:00:00on 4th portfolio
# skipped1994-03-01 00:00:00on 4th portfolio
# review_pf_signal done
# skipped1963-09-01 00:00:00on 4th portfolio
# skipped1964-02-01 00:00:00on 4th portfolio
# skipped1964-03-01 00:00:00on 4th portfolio
# skipped1964-04-01 00:00:00on 4th portfolio
# skipped1964-05-01 00:00:00on 4th portfolio
# skipped1964-05-01 00:00:00on 9th portfolio
# skipped1964-08-01 00:00:00on 9th portfolio
# skipped1965-04-01 00:00:00on 4th portfolio
# skipped1965-04-01 00:00:00on 9th portfolio
# skipped1965-05-01 00:00:00on 4th portfolio
# skipped1965-06-01 00:00:00on 4th portfolio
# skipped1965-08-01 00:00:00on 9th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 9th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1965-11-01 00:00:00on 9th portfolio
# skipped1965-12-01 00:00:00on 9th portfolio
# skipped1966-01-01 00:00:00on 9th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 9th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-03-01 00:00:00on 9th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 9th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 14th portfolio
# skipped1966-06-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 9th portfolio
# skipped1966-08-01 00:00:00on 4th portfolio
# skipped1966-10-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 9th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 9th portfolio
# skipped1967-02-01 00:00:00on 4th portfolio
# skipped1967-03-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 9th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 9th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1968-04-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 4th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1968-08-01 00:00:00on 4th portfolio
# skipped1968-09-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 3th portfolio
# skipped1968-12-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 9th portfolio
# skipped1969-05-01 00:00:00on 4th portfolio
# skipped1969-07-01 00:00:00on 4th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1969-09-01 00:00:00on 4th portfolio
# skipped1969-10-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-04-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 3th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 3th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 9th portfolio
# skipped1971-01-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 9th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-04-01 00:00:00on 3th portfolio
# skipped1971-04-01 00:00:00on 9th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 9th portfolio
# skipped1971-06-01 00:00:00on 4th portfolio
# skipped1971-08-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 9th portfolio
# skipped1972-02-01 00:00:00on 3th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-05-01 00:00:00on 3th portfolio
# skipped1972-05-01 00:00:00on 9th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-04-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 4th portfolio
# skipped1994-02-01 00:00:00on 4th portfolio
# skipped1994-03-01 00:00:00on 4th portfolio
# review_pf_return done
# ..write toM_VOL_L_VOL_48_True
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_72W_lag_lag_True1963-07-2016-12
# skipped1963-09-01 00:00:00on 4th portfolio
# skipped1963-11-01 00:00:00on 4th portfolio
# skipped1964-01-01 00:00:00on 4th portfolio
# skipped1964-02-01 00:00:00on 3th portfolio
# skipped1964-03-01 00:00:00on 9th portfolio
# skipped1964-05-01 00:00:00on 4th portfolio
# skipped1964-08-01 00:00:00on 4th portfolio
# skipped1964-08-01 00:00:00on 9th portfolio
# skipped1965-01-01 00:00:00on 4th portfolio
# skipped1965-01-01 00:00:00on 9th portfolio
# skipped1965-02-01 00:00:00on 9th portfolio
# skipped1965-04-01 00:00:00on 4th portfolio
# skipped1965-04-01 00:00:00on 9th portfolio
# skipped1965-05-01 00:00:00on 3th portfolio
# skipped1965-05-01 00:00:00on 4th portfolio
# skipped1965-06-01 00:00:00on 4th portfolio
# skipped1965-07-01 00:00:00on 9th portfolio
# skipped1965-08-01 00:00:00on 3th portfolio
# skipped1965-08-01 00:00:00on 9th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 9th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1965-11-01 00:00:00on 9th portfolio
# skipped1965-12-01 00:00:00on 9th portfolio
# skipped1966-01-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 9th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 9th portfolio
# skipped1966-08-01 00:00:00on 4th portfolio
# skipped1966-11-01 00:00:00on 9th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 9th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 9th portfolio
# skipped1967-02-01 00:00:00on 9th portfolio
# skipped1967-03-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-05-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 9th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1967-10-01 00:00:00on 9th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1967-12-01 00:00:00on 3th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 9th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 9th portfolio
# skipped1968-04-01 00:00:00on 4th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1968-07-01 00:00:00on 4th portfolio
# skipped1968-09-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 9th portfolio
# skipped1969-02-01 00:00:00on 9th portfolio
# skipped1969-03-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 9th portfolio
# skipped1969-05-01 00:00:00on 4th portfolio
# skipped1969-07-01 00:00:00on 4th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1969-10-01 00:00:00on 4th portfolio
# skipped1969-11-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-02-01 00:00:00on 4th portfolio
# skipped1970-04-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 9th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 3th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 9th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 3th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 9th portfolio
# skipped1971-01-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 9th portfolio
# skipped1971-03-01 00:00:00on 3th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-03-01 00:00:00on 9th portfolio
# skipped1971-04-01 00:00:00on 9th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 9th portfolio
# skipped1971-06-01 00:00:00on 4th portfolio
# skipped1971-07-01 00:00:00on 9th portfolio
# skipped1971-09-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 9th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-03-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-04-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 4th portfolio
# skipped1973-08-01 00:00:00on 20th portfolio
# skipped1973-09-01 00:00:00on 9th portfolio
# skipped1991-04-01 00:00:00on 4th portfolio
# skipped1994-11-01 00:00:00on 4th portfolio
# skipped1995-04-01 00:00:00on 9th portfolio
# skipped1996-04-01 00:00:00on 4th portfolio
# skipped1996-08-01 00:00:00on 4th portfolio
# review_pf_signal done
# skipped1963-09-01 00:00:00on 4th portfolio
# skipped1963-11-01 00:00:00on 4th portfolio
# skipped1964-01-01 00:00:00on 4th portfolio
# skipped1964-02-01 00:00:00on 3th portfolio
# skipped1964-03-01 00:00:00on 9th portfolio
# skipped1964-05-01 00:00:00on 4th portfolio
# skipped1964-08-01 00:00:00on 4th portfolio
# skipped1964-08-01 00:00:00on 9th portfolio
# skipped1965-01-01 00:00:00on 4th portfolio
# skipped1965-01-01 00:00:00on 9th portfolio
# skipped1965-02-01 00:00:00on 9th portfolio
# skipped1965-04-01 00:00:00on 4th portfolio
# skipped1965-04-01 00:00:00on 9th portfolio
# skipped1965-05-01 00:00:00on 3th portfolio
# skipped1965-05-01 00:00:00on 4th portfolio
# skipped1965-06-01 00:00:00on 4th portfolio
# skipped1965-07-01 00:00:00on 9th portfolio
# skipped1965-08-01 00:00:00on 3th portfolio
# skipped1965-08-01 00:00:00on 9th portfolio
# skipped1965-09-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 9th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1965-11-01 00:00:00on 9th portfolio
# skipped1965-12-01 00:00:00on 9th portfolio
# skipped1966-01-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 9th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-05-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 9th portfolio
# skipped1966-08-01 00:00:00on 4th portfolio
# skipped1966-11-01 00:00:00on 9th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 9th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 9th portfolio
# skipped1967-02-01 00:00:00on 9th portfolio
# skipped1967-03-01 00:00:00on 4th portfolio
# skipped1967-04-01 00:00:00on 4th portfolio
# skipped1967-05-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 4th portfolio
# skipped1967-08-01 00:00:00on 4th portfolio
# skipped1967-09-01 00:00:00on 9th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1967-10-01 00:00:00on 9th portfolio
# skipped1967-11-01 00:00:00on 4th portfolio
# skipped1967-12-01 00:00:00on 3th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 9th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 9th portfolio
# skipped1968-04-01 00:00:00on 4th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1968-07-01 00:00:00on 4th portfolio
# skipped1968-09-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 9th portfolio
# skipped1969-02-01 00:00:00on 9th portfolio
# skipped1969-03-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 9th portfolio
# skipped1969-05-01 00:00:00on 4th portfolio
# skipped1969-07-01 00:00:00on 4th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1969-10-01 00:00:00on 4th portfolio
# skipped1969-11-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-02-01 00:00:00on 4th portfolio
# skipped1970-04-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 9th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 3th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 9th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 3th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 9th portfolio
# skipped1971-01-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 9th portfolio
# skipped1971-03-01 00:00:00on 3th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-03-01 00:00:00on 9th portfolio
# skipped1971-04-01 00:00:00on 9th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 9th portfolio
# skipped1971-06-01 00:00:00on 4th portfolio
# skipped1971-07-01 00:00:00on 9th portfolio
# skipped1971-09-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 9th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-03-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-04-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 4th portfolio
# skipped1973-08-01 00:00:00on 20th portfolio
# skipped1973-09-01 00:00:00on 9th portfolio
# skipped1991-04-01 00:00:00on 4th portfolio
# skipped1994-11-01 00:00:00on 4th portfolio
# skipped1995-04-01 00:00:00on 9th portfolio
# skipped1996-04-01 00:00:00on 4th portfolio
# skipped1996-08-01 00:00:00on 4th portfolio
# review_pf_return done
# ..write toM_VOL_L_VOL_72_True
# Analyze and aggregate:  pfweight_M_VOL_lag_False1963-07-2016-12
# review_pf_signal done
# review_pf_return done
# ..write toM_VOL_False
# Analyze and aggregate:  pfweight_L_VOL_24W_lag_lag_False1963-07-2016-12
# review_pf_signal done
# review_pf_return done
# ..write toL_VOL_24W_lag_False
# Analyze and aggregate:  pfweight_L_VOL_48W_lag_lag_False1963-07-2016-12
# review_pf_signal done
# review_pf_return done
# ..write toL_VOL_48W_lag_False
# Analyze and aggregate:  pfweight_L_VOL_72W_lag_lag_False1963-07-2016-12
# review_pf_signal done
# review_pf_return done
# ..write toL_VOL_72W_lag_False
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_24W_lag_lag_False1963-07-2016-12
# skipped1964-02-01 00:00:00on 4th portfolio
# skipped1964-03-01 00:00:00on 4th portfolio
# skipped1964-04-01 00:00:00on 20th portfolio
# skipped1964-05-01 00:00:00on 4th portfolio
# skipped1964-07-01 00:00:00on 20th portfolio
# skipped1965-08-01 00:00:00on 4th portfolio
# skipped1966-01-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1969-09-01 00:00:00on 20th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1971-04-01 00:00:00on 20th portfolio
# skipped1971-05-01 00:00:00on 20th portfolio
# skipped1971-07-01 00:00:00on 4th portfolio
# skipped1971-07-01 00:00:00on 20th portfolio
# skipped1973-10-01 00:00:00on 20th portfolio
# review_pf_signal done
# skipped1964-02-01 00:00:00on 4th portfolio
# skipped1964-03-01 00:00:00on 4th portfolio
# skipped1964-04-01 00:00:00on 20th portfolio
# skipped1964-05-01 00:00:00on 4th portfolio
# skipped1964-07-01 00:00:00on 20th portfolio
# skipped1965-08-01 00:00:00on 4th portfolio
# skipped1966-01-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1967-12-01 00:00:00on 4th portfolio
# skipped1969-09-01 00:00:00on 20th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1971-04-01 00:00:00on 20th portfolio
# skipped1971-05-01 00:00:00on 20th portfolio
# skipped1971-07-01 00:00:00on 4th portfolio
# skipped1971-07-01 00:00:00on 20th portfolio
# skipped1973-10-01 00:00:00on 20th portfolio
# review_pf_return done
# ..write toM_VOL_L_VOL_24_False
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_48W_lag_lag_False1963-07-2016-12
# skipped1964-02-01 00:00:00on 4th portfolio
# skipped1964-03-01 00:00:00on 4th portfolio
# skipped1964-05-01 00:00:00on 4th portfolio
# skipped1964-07-01 00:00:00on 20th portfolio
# skipped1965-04-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 20th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 4th portfolio
# skipped1966-10-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1969-09-01 00:00:00on 20th portfolio
# skipped1969-11-01 00:00:00on 20th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 20th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-08-01 00:00:00on 20th portfolio
# skipped1971-10-01 00:00:00on 20th portfolio
# skipped1972-01-01 00:00:00on 20th portfolio
# skipped1973-08-01 00:00:00on 20th portfolio
# skipped1973-10-01 00:00:00on 20th portfolio
# review_pf_signal done
# skipped1964-02-01 00:00:00on 4th portfolio
# skipped1964-03-01 00:00:00on 4th portfolio
# skipped1964-05-01 00:00:00on 4th portfolio
# skipped1964-07-01 00:00:00on 20th portfolio
# skipped1965-04-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 20th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 4th portfolio
# skipped1966-10-01 00:00:00on 4th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1969-09-01 00:00:00on 20th portfolio
# skipped1969-11-01 00:00:00on 20th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 20th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1971-08-01 00:00:00on 20th portfolio
# skipped1971-10-01 00:00:00on 20th portfolio
# skipped1972-01-01 00:00:00on 20th portfolio
# skipped1973-08-01 00:00:00on 20th portfolio
# skipped1973-10-01 00:00:00on 20th portfolio
# review_pf_return done
# ..write toM_VOL_L_VOL_48_False
# Analyze and aggregate:  pfweight_M_VOL_lag_L_VOL_72W_lag_lag_False1963-07-2016-12
# skipped1964-07-01 00:00:00on 20th portfolio
# skipped1964-08-01 00:00:00on 4th portfolio
# skipped1965-01-01 00:00:00on 4th portfolio
# skipped1965-04-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 4th portfolio
# skipped1966-10-01 00:00:00on 20th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 20th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1969-09-01 00:00:00on 20th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 20th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 20th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 20th portfolio
# skipped1972-02-01 00:00:00on 20th portfolio
# skipped1972-06-01 00:00:00on 20th portfolio
# skipped1973-06-01 00:00:00on 20th portfolio
# skipped1973-08-01 00:00:00on 20th portfolio
# skipped1973-09-01 00:00:00on 20th portfolio
# skipped1973-10-01 00:00:00on 20th portfolio
# review_pf_signal done
# skipped1964-07-01 00:00:00on 20th portfolio
# skipped1964-08-01 00:00:00on 4th portfolio
# skipped1965-01-01 00:00:00on 4th portfolio
# skipped1965-04-01 00:00:00on 4th portfolio
# skipped1965-10-01 00:00:00on 4th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1966-02-01 00:00:00on 4th portfolio
# skipped1966-04-01 00:00:00on 4th portfolio
# skipped1966-06-01 00:00:00on 4th portfolio
# skipped1966-10-01 00:00:00on 20th portfolio
# skipped1966-12-01 00:00:00on 4th portfolio
# skipped1967-01-01 00:00:00on 4th portfolio
# skipped1967-06-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 20th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1968-01-01 00:00:00on 4th portfolio
# skipped1968-03-01 00:00:00on 4th portfolio
# skipped1968-12-01 00:00:00on 4th portfolio
# skipped1969-04-01 00:00:00on 4th portfolio
# skipped1969-09-01 00:00:00on 20th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 20th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-07-01 00:00:00on 20th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-05-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 20th portfolio
# skipped1972-02-01 00:00:00on 20th portfolio
# skipped1972-06-01 00:00:00on 20th portfolio
# skipped1973-06-01 00:00:00on 20th portfolio
# skipped1973-08-01 00:00:00on 20th portfolio
# skipped1973-09-01 00:00:00on 20th portfolio
# skipped1973-10-01 00:00:00on 20th portfolio
# review_pf_return done
# ..write toM_VOL_L_VOL_72_False

# %% [markdown]
# ### 4.2.2 Idio Vol

# %%
list_execute = [['FF_M_VOL_lag'], 
                ['FF_L_VOL_24W_lag_lag'],
                ['FF_L_VOL_48W_lag_lag'],
                ['FF_L_VOL_72W_lag_lag'],
                ['FF_M_VOL_lag', 'FF_L_VOL_24W_lag_lag'],
                ['FF_M_VOL_lag', 'FF_L_VOL_48W_lag_lag'],
                ['FF_M_VOL_lag', 'FF_L_VOL_72W_lag_lag']
                ]

startdate = datetime.datetime(1965, 2, 1)
enddate = datetime.datetime(2016, 12, 31)
nyse_break_list = [True, False]
wrapper_analysis_write('analysis_weekly_idio0303.xlsx','1963-07-2016-12', list_execute, startdate, enddate, nyse_break_list)

# %% [markdown]
# ## 4.3 Vol and Other Factors
# ### 4.3.1 With Indicative Fee

# %%
list_execute = [['M_VOL_lag'], ['FF_M_VOL_lag'], ['IndicativeFee'],
                ['M_VOL_lag', 'IndicativeFee_lag'],
                ['FF_M_VOL_lag', 'IndicativeFee_lag']
                ]

date_list = [datetime.datetime(2004, 1, 1), datetime.datetime(2016, 12, 31)]

nyse_break_list = [True, False]
wrapper_analysis_write('analysis_shortfee0303.xlsx','2004-01-2016-12', list_execute, date_list[0], date_list[1], nyse_break_list)

# %% [markdown]
# ### 4.3.2 With Size and Momentum

# %%
list_execute = [['M_VOL_lag'], ['FF_M_VOL_lag'], ['MKTCAP_M_lag'], ['M_RET_lag'],
                ['M_VOL_lag', 'MKTCAP_M_lag'],
                ['FF_M_VOL_lag', 'MKTCAP_M_lag'],
                ['M_VOL_lag', 'M_RET_lag'],
                ['FF_M_VOL_lag', 'M_RET_lag'],
                ]
date_list = [datetime.datetime(1963, 7, 1), datetime.datetime(2016, 12, 31)]
nyse_break_list = [True, False]
wrapper_analysis_write('analysis_size_reversal0303.xlsx','1963-07-2016-12', list_execute, date_list[0], date_list[1], nyse_break_list)
# Out:
# Analyze and aggregate:  pfweight_M_VOL_lag_True1963-07-2016-12
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_True1963-07-2016-12
# Analyze and aggregate:  pfweight_MKTCAP_M_lag_True1963-07-2016-12
# Analyze and aggregate:  pfweight_M_RET_lag_True1963-07-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_MKTCAP_M_lag_True1963-07-2016-12
# skipped1964-05-01 00:00:00on 0th portfolio
# skipped1965-09-01 00:00:00on 0th portfolio
# skipped1965-10-01 00:00:00on 0th portfolio
# skipped1970-07-01 00:00:00on 0th portfolio
# skipped1970-12-01 00:00:00on 0th portfolio
# skipped1971-02-01 00:00:00on 0th portfolio
# skipped1971-03-01 00:00:00on 5th portfolio
# skipped1971-05-01 00:00:00on 0th portfolio
# skipped1972-07-01 00:00:00on 0th portfolio
# skipped1973-09-01 00:00:00on 0th portfolio
# skipped1964-05-01 00:00:00on 0th portfolio
# skipped1965-09-01 00:00:00on 0th portfolio
# skipped1965-10-01 00:00:00on 0th portfolio
# skipped1970-07-01 00:00:00on 0th portfolio
# skipped1970-12-01 00:00:00on 0th portfolio
# skipped1971-02-01 00:00:00on 0th portfolio
# skipped1971-03-01 00:00:00on 5th portfolio
# skipped1971-05-01 00:00:00on 0th portfolio
# skipped1972-07-01 00:00:00on 0th portfolio
# skipped1973-09-01 00:00:00on 0th portfolio
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_MKTCAP_M_lag_True1963-07-2016-12
# skipped1964-05-01 00:00:00on 0th portfolio
# skipped1965-06-01 00:00:00on 0th portfolio
# skipped1965-08-01 00:00:00on 0th portfolio
# skipped1965-09-01 00:00:00on 0th portfolio
# skipped1965-10-01 00:00:00on 0th portfolio
# skipped1970-07-01 00:00:00on 0th portfolio
# skipped1970-09-01 00:00:00on 0th portfolio
# skipped1970-12-01 00:00:00on 0th portfolio
# skipped1971-03-01 00:00:00on 0th portfolio
# skipped1971-05-01 00:00:00on 0th portfolio
# skipped1971-07-01 00:00:00on 0th portfolio
# skipped1993-04-01 00:00:00on 0th portfolio
# skipped1964-05-01 00:00:00on 0th portfolio
# skipped1965-06-01 00:00:00on 0th portfolio
# skipped1965-08-01 00:00:00on 0th portfolio
# skipped1965-09-01 00:00:00on 0th portfolio
# skipped1965-10-01 00:00:00on 0th portfolio
# skipped1970-07-01 00:00:00on 0th portfolio
# skipped1970-09-01 00:00:00on 0th portfolio
# skipped1970-12-01 00:00:00on 0th portfolio
# skipped1971-03-01 00:00:00on 0th portfolio
# skipped1971-05-01 00:00:00on 0th portfolio
# skipped1971-07-01 00:00:00on 0th portfolio
# skipped1993-04-01 00:00:00on 0th portfolio
# Analyze and aggregate:  pfweight_M_VOL_lag_M_RET_lag_True1963-07-2016-12
# skipped1964-10-01 00:00:00on 4th portfolio
# skipped1965-07-01 00:00:00on 0th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1965-12-01 00:00:00on 4th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1967-02-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 9th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 4th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1969-07-01 00:00:00on 0th portfolio
# skipped1969-10-01 00:00:00on 0th portfolio
# skipped1970-05-01 00:00:00on 0th portfolio
# skipped1970-10-01 00:00:00on 9th portfolio
# skipped1970-11-01 00:00:00on 0th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1973-08-01 00:00:00on 4th portfolio
# skipped1978-04-01 00:00:00on 4th portfolio
# skipped1978-11-01 00:00:00on 0th portfolio
# skipped1978-11-01 00:00:00on 1th portfolio
# skipped1978-11-01 00:00:00on 5th portfolio
# skipped1979-02-01 00:00:00on 4th portfolio
# skipped1996-05-01 00:00:00on 4th portfolio
# skipped1996-08-01 00:00:00on 0th portfolio
# skipped2000-03-01 00:00:00on 4th portfolio
# skipped2000-12-01 00:00:00on 0th portfolio
# skipped2001-03-01 00:00:00on 0th portfolio
# skipped2001-09-01 00:00:00on 0th portfolio
# skipped2004-02-01 00:00:00on 4th portfolio
# skipped2014-12-01 00:00:00on 0th portfolio
# skipped1964-10-01 00:00:00on 4th portfolio
# skipped1965-07-01 00:00:00on 0th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1965-12-01 00:00:00on 4th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1967-02-01 00:00:00on 4th portfolio
# skipped1967-07-01 00:00:00on 9th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1968-05-01 00:00:00on 4th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1969-07-01 00:00:00on 0th portfolio
# skipped1969-10-01 00:00:00on 0th portfolio
# skipped1970-05-01 00:00:00on 0th portfolio
# skipped1970-10-01 00:00:00on 9th portfolio
# skipped1970-11-01 00:00:00on 0th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1973-08-01 00:00:00on 4th portfolio
# skipped1978-04-01 00:00:00on 4th portfolio
# skipped1978-11-01 00:00:00on 0th portfolio
# skipped1978-11-01 00:00:00on 1th portfolio
# skipped1978-11-01 00:00:00on 5th portfolio
# skipped1979-02-01 00:00:00on 4th portfolio
# skipped1996-05-01 00:00:00on 4th portfolio
# skipped1996-08-01 00:00:00on 0th portfolio
# skipped2000-03-01 00:00:00on 4th portfolio
# skipped2000-12-01 00:00:00on 0th portfolio
# skipped2001-03-01 00:00:00on 0th portfolio
# skipped2001-09-01 00:00:00on 0th portfolio
# skipped2004-02-01 00:00:00on 4th portfolio
# skipped2014-12-01 00:00:00on 0th portfolio
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_M_RET_lag_True1963-07-2016-12
# skipped1965-07-01 00:00:00on 0th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1965-12-01 00:00:00on 4th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-11-01 00:00:00on 0th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1969-07-01 00:00:00on 0th portfolio
# skipped1970-01-01 00:00:00on 0th portfolio
# skipped1970-05-01 00:00:00on 0th portfolio
# skipped1970-10-01 00:00:00on 9th portfolio
# skipped1970-11-01 00:00:00on 0th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1973-07-01 00:00:00on 0th portfolio
# skipped1973-08-01 00:00:00on 4th portfolio
# skipped1976-02-01 00:00:00on 4th portfolio
# skipped1978-11-01 00:00:00on 0th portfolio
# skipped1979-04-01 00:00:00on 4th portfolio
# skipped1980-01-01 00:00:00on 4th portfolio
# skipped1985-02-01 00:00:00on 4th portfolio
# skipped1991-02-01 00:00:00on 4th portfolio
# skipped1991-03-01 00:00:00on 4th portfolio
# skipped1992-02-01 00:00:00on 4th portfolio
# skipped1992-12-01 00:00:00on 4th portfolio
# skipped1996-05-01 00:00:00on 4th portfolio
# skipped1996-06-01 00:00:00on 4th portfolio
# skipped1996-08-01 00:00:00on 0th portfolio
# skipped1997-06-01 00:00:00on 4th portfolio
# skipped2000-03-01 00:00:00on 4th portfolio
# skipped2000-12-01 00:00:00on 0th portfolio
# skipped1965-07-01 00:00:00on 0th portfolio
# skipped1965-11-01 00:00:00on 4th portfolio
# skipped1965-12-01 00:00:00on 4th portfolio
# skipped1966-03-01 00:00:00on 4th portfolio
# skipped1966-11-01 00:00:00on 0th portfolio
# skipped1967-10-01 00:00:00on 4th portfolio
# skipped1968-06-01 00:00:00on 4th portfolio
# skipped1969-07-01 00:00:00on 0th portfolio
# skipped1970-01-01 00:00:00on 0th portfolio
# skipped1970-05-01 00:00:00on 0th portfolio
# skipped1970-10-01 00:00:00on 9th portfolio
# skipped1970-11-01 00:00:00on 0th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1973-07-01 00:00:00on 0th portfolio
# skipped1973-08-01 00:00:00on 4th portfolio
# skipped1976-02-01 00:00:00on 4th portfolio
# skipped1978-11-01 00:00:00on 0th portfolio
# skipped1979-04-01 00:00:00on 4th portfolio
# skipped1980-01-01 00:00:00on 4th portfolio
# skipped1985-02-01 00:00:00on 4th portfolio
# skipped1991-02-01 00:00:00on 4th portfolio
# skipped1991-03-01 00:00:00on 4th portfolio
# skipped1992-02-01 00:00:00on 4th portfolio
# skipped1992-12-01 00:00:00on 4th portfolio
# skipped1996-05-01 00:00:00on 4th portfolio
# skipped1996-06-01 00:00:00on 4th portfolio
# skipped1996-08-01 00:00:00on 0th portfolio
# skipped1997-06-01 00:00:00on 4th portfolio
# skipped2000-03-01 00:00:00on 4th portfolio
# skipped2000-12-01 00:00:00on 0th portfolio
# Analyze and aggregate:  pfweight_M_VOL_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_MKTCAP_M_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_M_RET_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_MKTCAP_M_lag_False1963-07-2016-12
# skipped1965-04-01 00:00:00on 24th portfolio
# skipped1967-07-01 00:00:00on 24th portfolio
# skipped1971-02-01 00:00:00on 24th portfolio
# skipped1965-04-01 00:00:00on 24th portfolio
# skipped1967-07-01 00:00:00on 24th portfolio
# skipped1971-02-01 00:00:00on 24th portfolio
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_MKTCAP_M_lag_False1963-07-2016-12
# skipped1964-11-01 00:00:00on 24th portfolio
# skipped1965-04-01 00:00:00on 24th portfolio
# skipped1965-05-01 00:00:00on 24th portfolio
# skipped1965-06-01 00:00:00on 24th portfolio
# skipped1970-12-01 00:00:00on 24th portfolio
# skipped1971-01-01 00:00:00on 24th portfolio
# skipped1971-02-01 00:00:00on 24th portfolio
# skipped1964-11-01 00:00:00on 24th portfolio
# skipped1965-04-01 00:00:00on 24th portfolio
# skipped1965-05-01 00:00:00on 24th portfolio
# skipped1965-06-01 00:00:00on 24th portfolio
# skipped1970-12-01 00:00:00on 24th portfolio
# skipped1971-01-01 00:00:00on 24th portfolio
# skipped1971-02-01 00:00:00on 24th portfolio
# Analyze and aggregate:  pfweight_M_VOL_lag_M_RET_lag_False1963-07-2016-12
# skipped1978-04-01 00:00:00on 4th portfolio
# skipped1978-11-01 00:00:00on 0th portfolio
# skipped1980-12-01 00:00:00on 4th portfolio
# skipped2000-03-01 00:00:00on 4th portfolio
# skipped1978-04-01 00:00:00on 4th portfolio
# skipped1978-11-01 00:00:00on 0th portfolio
# skipped1980-12-01 00:00:00on 4th portfolio
# skipped2000-03-01 00:00:00on 4th portfolio
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_M_RET_lag_False1963-07-2016-12
# skipped1980-01-01 00:00:00on 4th portfolio
# skipped1980-01-01 00:00:00on 4th portfolio

# %%
list_execute = [['M_VOL_lag'], ['FF_M_VOL_lag'], ['MKTCAP_M_lag'], ['M_RET_lag'],
                ['M_VOL_lag', 'MKTCAP_M_lag'],
                ['FF_M_VOL_lag', 'MKTCAP_M_lag'],
                ['M_VOL_lag', 'M_RET_lag'],
                ['FF_M_VOL_lag', 'M_RET_lag'],
                ]
# date_list = [datetime.datetime(2004, 1, 1), datetime.datetime(2016, 12, 31)]
# nyse_break_list = [ False]
# wrapper_analysis_write('analysis_size_reversal_aft2004.xlsx','1963-07-2016-12',
#                        list_execute, date_list[0], date_list[1], nyse_break_list)


date_list = [datetime.datetime(2001, 1, 1), datetime.datetime(2016, 12, 31)]
nyse_break_list = [ False]
wrapper_analysis_write('analysis_size_reversal_aft2001.xlsx','1963-07-2016-12',
                       list_execute, date_list[0], date_list[1], nyse_break_list)

date_list = [datetime.datetime(1963, 7, 1), datetime.datetime(2000, 12, 31)]
nyse_break_list = [ False]
wrapper_analysis_write('analysis_size_reversal_bef2001.xlsx','1963-07-2016-12',
                       list_execute, date_list[0], date_list[1], nyse_break_list)
# Out:
# Analyze and aggregate:  pfweight_M_VOL_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_MKTCAP_M_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_M_RET_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_MKTCAP_M_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_MKTCAP_M_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_M_RET_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_M_RET_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_MKTCAP_M_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_M_RET_lag_False1963-07-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_MKTCAP_M_lag_False1963-07-2016-12
# skipped1965-04-01 00:00:00on 24th portfolio
# skipped1967-07-01 00:00:00on 24th portfolio
# skipped1971-02-01 00:00:00on 24th portfolio
# skipped1965-04-01 00:00:00on 24th portfolio
# skipped1967-07-01 00:00:00on 24th portfolio
# skipped1971-02-01 00:00:00on 24th portfolio
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_MKTCAP_M_lag_False1963-07-2016-12
# skipped1964-11-01 00:00:00on 24th portfolio
# skipped1965-04-01 00:00:00on 24th portfolio
# skipped1965-05-01 00:00:00on 24th portfolio
# skipped1965-06-01 00:00:00on 24th portfolio
# skipped1970-12-01 00:00:00on 24th portfolio
# skipped1971-01-01 00:00:00on 24th portfolio
# skipped1971-02-01 00:00:00on 24th portfolio
# skipped1964-11-01 00:00:00on 24th portfolio
# skipped1965-04-01 00:00:00on 24th portfolio
# skipped1965-05-01 00:00:00on 24th portfolio
# skipped1965-06-01 00:00:00on 24th portfolio
# skipped1970-12-01 00:00:00on 24th portfolio
# skipped1971-01-01 00:00:00on 24th portfolio
# skipped1971-02-01 00:00:00on 24th portfolio
# Analyze and aggregate:  pfweight_M_VOL_lag_M_RET_lag_False1963-07-2016-12
# skipped1978-04-01 00:00:00on 4th portfolio
# skipped1978-11-01 00:00:00on 0th portfolio
# skipped1980-12-01 00:00:00on 4th portfolio
# skipped2000-03-01 00:00:00on 4th portfolio
# skipped1978-04-01 00:00:00on 4th portfolio
# skipped1978-11-01 00:00:00on 0th portfolio
# skipped1980-12-01 00:00:00on 4th portfolio
# skipped2000-03-01 00:00:00on 4th portfolio
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_M_RET_lag_False1963-07-2016-12
# skipped1980-01-01 00:00:00on 4th portfolio
# skipped1980-01-01 00:00:00on 4th portfolio

# %% [markdown]
# ### 4.3.3 With beta

# %%
list_execute = [['M_VOL_lag'], ['FF_M_VOL_lag'], ['beta_lag'],
                ['M_VOL_lag', 'beta_lag'],
                ['FF_M_VOL_lag', 'beta_lag'],
                ]
date_list = [datetime.datetime(1968, 7, 1), datetime.datetime(2016, 12, 31)]
nyse_break_list = [True, False]
wrapper_analysis_write('analysis_beta0303.xlsx','1968-07-2016-12', list_execute, date_list[0], date_list[1], nyse_break_list)
# Out:
# Analyze and aggregate:  pfweight_M_VOL_lag_True1968-07-2016-12
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_True1968-07-2016-12
# Analyze and aggregate:  pfweight_beta_lag_True1968-07-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_beta_lag_True1968-07-2016-12
# skipped1968-09-01 00:00:00on 4th portfolio
# skipped1969-06-01 00:00:00on 4th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-02-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 9th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 9th portfolio
# skipped1970-06-01 00:00:00on 14th portfolio
# skipped1970-07-01 00:00:00on 3th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 3th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 9th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 9th portfolio
# skipped1970-11-01 00:00:00on 4th portfolio
# skipped1970-11-01 00:00:00on 9th portfolio
# skipped1970-12-01 00:00:00on 9th portfolio
# skipped1971-01-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-04-01 00:00:00on 4th portfolio
# skipped1971-06-01 00:00:00on 4th portfolio
# skipped1971-07-01 00:00:00on 4th portfolio
# skipped1971-08-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 4th portfolio
# skipped1971-12-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 3th portfolio
# skipped1972-01-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 9th portfolio
# skipped1972-02-01 00:00:00on 14th portfolio
# skipped1972-03-01 00:00:00on 4th portfolio
# skipped1972-04-01 00:00:00on 9th portfolio
# skipped1972-05-01 00:00:00on 4th portfolio
# skipped1972-06-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 9th portfolio
# skipped1972-09-01 00:00:00on 9th portfolio
# skipped1972-10-01 00:00:00on 4th portfolio
# skipped1972-11-01 00:00:00on 4th portfolio
# skipped1972-11-01 00:00:00on 9th portfolio
# skipped1972-12-01 00:00:00on 4th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-02-01 00:00:00on 3th portfolio
# skipped1973-04-01 00:00:00on 4th portfolio
# skipped1973-05-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 3th portfolio
# skipped1973-06-01 00:00:00on 4th portfolio
# skipped1973-07-01 00:00:00on 4th portfolio
# skipped1973-07-01 00:00:00on 9th portfolio
# skipped1973-08-01 00:00:00on 4th portfolio
# skipped1973-12-01 00:00:00on 4th portfolio
# skipped1974-01-01 00:00:00on 4th portfolio
# skipped1974-03-01 00:00:00on 4th portfolio
# skipped1974-09-01 00:00:00on 4th portfolio
# skipped1974-10-01 00:00:00on 4th portfolio
# skipped1975-10-01 00:00:00on 4th portfolio
# skipped1976-02-01 00:00:00on 4th portfolio
# skipped1987-11-01 00:00:00on 4th portfolio
# skipped1990-10-01 00:00:00on 4th portfolio
# skipped1990-11-01 00:00:00on 4th portfolio
# skipped1991-04-01 00:00:00on 4th portfolio
# skipped1992-03-01 00:00:00on 4th portfolio
# skipped1998-10-01 00:00:00on 4th portfolio
# skipped2000-05-01 00:00:00on 4th portfolio
# skipped2008-11-01 00:00:00on 4th portfolio
# skipped2009-02-01 00:00:00on 4th portfolio
# skipped2011-12-01 00:00:00on 4th portfolio
# skipped1968-09-01 00:00:00on 4th portfolio
# skipped1969-06-01 00:00:00on 4th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-02-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 9th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 9th portfolio
# skipped1970-06-01 00:00:00on 14th portfolio
# skipped1970-07-01 00:00:00on 3th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 3th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 9th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 9th portfolio
# skipped1970-11-01 00:00:00on 4th portfolio
# skipped1970-11-01 00:00:00on 9th portfolio
# skipped1970-12-01 00:00:00on 9th portfolio
# skipped1971-01-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-04-01 00:00:00on 4th portfolio
# skipped1971-06-01 00:00:00on 4th portfolio
# skipped1971-07-01 00:00:00on 4th portfolio
# skipped1971-08-01 00:00:00on 4th portfolio
# skipped1971-09-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 4th portfolio
# skipped1971-12-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 3th portfolio
# skipped1972-01-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 9th portfolio
# skipped1972-02-01 00:00:00on 14th portfolio
# skipped1972-03-01 00:00:00on 4th portfolio
# skipped1972-04-01 00:00:00on 9th portfolio
# skipped1972-05-01 00:00:00on 4th portfolio
# skipped1972-06-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 9th portfolio
# skipped1972-09-01 00:00:00on 9th portfolio
# skipped1972-10-01 00:00:00on 4th portfolio
# skipped1972-11-01 00:00:00on 4th portfolio
# skipped1972-11-01 00:00:00on 9th portfolio
# skipped1972-12-01 00:00:00on 4th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-02-01 00:00:00on 3th portfolio
# skipped1973-04-01 00:00:00on 4th portfolio
# skipped1973-05-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 3th portfolio
# skipped1973-06-01 00:00:00on 4th portfolio
# skipped1973-07-01 00:00:00on 4th portfolio
# skipped1973-07-01 00:00:00on 9th portfolio
# skipped1973-08-01 00:00:00on 4th portfolio
# skipped1973-12-01 00:00:00on 4th portfolio
# skipped1974-01-01 00:00:00on 4th portfolio
# skipped1974-03-01 00:00:00on 4th portfolio
# skipped1974-09-01 00:00:00on 4th portfolio
# skipped1974-10-01 00:00:00on 4th portfolio
# skipped1975-10-01 00:00:00on 4th portfolio
# skipped1976-02-01 00:00:00on 4th portfolio
# skipped1987-11-01 00:00:00on 4th portfolio
# skipped1990-10-01 00:00:00on 4th portfolio
# skipped1990-11-01 00:00:00on 4th portfolio
# skipped1991-04-01 00:00:00on 4th portfolio
# skipped1992-03-01 00:00:00on 4th portfolio
# skipped1998-10-01 00:00:00on 4th portfolio
# skipped2000-05-01 00:00:00on 4th portfolio
# skipped2008-11-01 00:00:00on 4th portfolio
# skipped2009-02-01 00:00:00on 4th portfolio
# skipped2011-12-01 00:00:00on 4th portfolio
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_beta_lag_True1968-07-2016-12
# skipped1968-09-01 00:00:00on 4th portfolio
# skipped1969-06-01 00:00:00on 4th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 9th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 9th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-11-01 00:00:00on 4th portfolio
# skipped1971-01-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-04-01 00:00:00on 4th portfolio
# skipped1971-07-01 00:00:00on 4th portfolio
# skipped1971-08-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 4th portfolio
# skipped1971-12-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 9th portfolio
# skipped1972-05-01 00:00:00on 4th portfolio
# skipped1972-05-01 00:00:00on 9th portfolio
# skipped1972-06-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1972-08-01 00:00:00on 9th portfolio
# skipped1972-11-01 00:00:00on 4th portfolio
# skipped1972-12-01 00:00:00on 4th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-03-01 00:00:00on 4th portfolio
# skipped1973-04-01 00:00:00on 4th portfolio
# skipped1973-05-01 00:00:00on 4th portfolio
# skipped1973-05-01 00:00:00on 9th portfolio
# skipped1973-06-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 9th portfolio
# skipped1973-07-01 00:00:00on 3th portfolio
# skipped1973-07-01 00:00:00on 4th portfolio
# skipped1973-08-01 00:00:00on 4th portfolio
# skipped1973-11-01 00:00:00on 4th portfolio
# skipped1973-12-01 00:00:00on 4th portfolio
# skipped1974-09-01 00:00:00on 4th portfolio
# skipped1990-12-01 00:00:00on 4th portfolio
# skipped1968-09-01 00:00:00on 4th portfolio
# skipped1969-06-01 00:00:00on 4th portfolio
# skipped1969-08-01 00:00:00on 4th portfolio
# skipped1970-01-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 9th portfolio
# skipped1970-07-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 9th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-11-01 00:00:00on 4th portfolio
# skipped1971-01-01 00:00:00on 4th portfolio
# skipped1971-02-01 00:00:00on 4th portfolio
# skipped1971-03-01 00:00:00on 4th portfolio
# skipped1971-04-01 00:00:00on 4th portfolio
# skipped1971-07-01 00:00:00on 4th portfolio
# skipped1971-08-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 4th portfolio
# skipped1971-12-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 9th portfolio
# skipped1972-05-01 00:00:00on 4th portfolio
# skipped1972-05-01 00:00:00on 9th portfolio
# skipped1972-06-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1972-08-01 00:00:00on 9th portfolio
# skipped1972-11-01 00:00:00on 4th portfolio
# skipped1972-12-01 00:00:00on 4th portfolio
# skipped1973-01-01 00:00:00on 4th portfolio
# skipped1973-03-01 00:00:00on 4th portfolio
# skipped1973-04-01 00:00:00on 4th portfolio
# skipped1973-05-01 00:00:00on 4th portfolio
# skipped1973-05-01 00:00:00on 9th portfolio
# skipped1973-06-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 9th portfolio
# skipped1973-07-01 00:00:00on 3th portfolio
# skipped1973-07-01 00:00:00on 4th portfolio
# skipped1973-08-01 00:00:00on 4th portfolio
# skipped1973-11-01 00:00:00on 4th portfolio
# skipped1973-12-01 00:00:00on 4th portfolio
# skipped1974-09-01 00:00:00on 4th portfolio
# skipped1990-12-01 00:00:00on 4th portfolio
# Analyze and aggregate:  pfweight_M_VOL_lag_False1968-07-2016-12
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_False1968-07-2016-12
# Analyze and aggregate:  pfweight_beta_lag_False1968-07-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_beta_lag_False1968-07-2016-12
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-11-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1972-11-01 00:00:00on 4th portfolio
# skipped1973-05-01 00:00:00on 4th portfolio
# skipped1973-07-01 00:00:00on 4th portfolio
# skipped1987-11-01 00:00:00on 4th portfolio
# skipped2008-11-01 00:00:00on 4th portfolio
# skipped2009-02-01 00:00:00on 4th portfolio
# skipped2011-12-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-11-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1972-11-01 00:00:00on 4th portfolio
# skipped1973-05-01 00:00:00on 4th portfolio
# skipped1973-07-01 00:00:00on 4th portfolio
# skipped1987-11-01 00:00:00on 4th portfolio
# skipped2008-11-01 00:00:00on 4th portfolio
# skipped2009-02-01 00:00:00on 4th portfolio
# skipped2011-12-01 00:00:00on 4th portfolio
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_beta_lag_False1968-07-2016-12
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1972-05-01 00:00:00on 4th portfolio
# skipped1973-05-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1972-05-01 00:00:00on 4th portfolio
# skipped1973-05-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 4th portfolio

# %%
list_execute = [['M_VOL_lag'], ['FF_M_VOL_lag'], ['beta_lag'],
                ['M_VOL_lag', 'beta_lag'],
                ['FF_M_VOL_lag', 'beta_lag'],
                ]
# date_list = [datetime.datetime(2004, 1, 1), datetime.datetime(2016, 12, 31)]
# nyse_break_list = [False]
# wrapper_analysis_write('analysis_beta_aft2004.xlsx','1968-07-2016-12', list_execute,
#                        date_list[0], date_list[1], nyse_break_list)


date_list = [datetime.datetime(2001, 1, 1), datetime.datetime(2016, 12, 31)]
nyse_break_list = [False]
wrapper_analysis_write('analysis_beta_aft2001.xlsx','1968-07-2016-12', list_execute,
                       date_list[0], date_list[1], nyse_break_list)

date_list = [datetime.datetime(1968, 7, 1), datetime.datetime(2000, 12, 31)]
nyse_break_list = [False]
wrapper_analysis_write('analysis_beta_bef2001.xlsx','1968-07-2016-12', list_execute,
                       date_list[0], date_list[1], nyse_break_list)
# Out:
# Analyze and aggregate:  pfweight_M_VOL_lag_False1968-07-2016-12
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_False1968-07-2016-12
# Analyze and aggregate:  pfweight_beta_lag_False1968-07-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_beta_lag_False1968-07-2016-12
# skipped2008-11-01 00:00:00on 4th portfolio
# skipped2009-02-01 00:00:00on 4th portfolio
# skipped2011-12-01 00:00:00on 4th portfolio
# skipped2008-11-01 00:00:00on 4th portfolio
# skipped2009-02-01 00:00:00on 4th portfolio
# skipped2011-12-01 00:00:00on 4th portfolio
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_beta_lag_False1968-07-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_False1968-07-2016-12
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_False1968-07-2016-12
# Analyze and aggregate:  pfweight_beta_lag_False1968-07-2016-12
# Analyze and aggregate:  pfweight_M_VOL_lag_beta_lag_False1968-07-2016-12
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-11-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1972-11-01 00:00:00on 4th portfolio
# skipped1973-05-01 00:00:00on 4th portfolio
# skipped1973-07-01 00:00:00on 4th portfolio
# skipped1987-11-01 00:00:00on 4th portfolio
# skipped1970-05-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1970-10-01 00:00:00on 4th portfolio
# skipped1970-11-01 00:00:00on 4th portfolio
# skipped1971-10-01 00:00:00on 4th portfolio
# skipped1971-11-01 00:00:00on 4th portfolio
# skipped1972-01-01 00:00:00on 4th portfolio
# skipped1972-02-01 00:00:00on 4th portfolio
# skipped1972-07-01 00:00:00on 4th portfolio
# skipped1972-11-01 00:00:00on 4th portfolio
# skipped1973-05-01 00:00:00on 4th portfolio
# skipped1973-07-01 00:00:00on 4th portfolio
# skipped1987-11-01 00:00:00on 4th portfolio
# Analyze and aggregate:  pfweight_FF_M_VOL_lag_beta_lag_False1968-07-2016-12
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1972-05-01 00:00:00on 4th portfolio
# skipped1973-05-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 4th portfolio
# skipped1970-06-01 00:00:00on 4th portfolio
# skipped1970-09-01 00:00:00on 4th portfolio
# skipped1972-05-01 00:00:00on 4th portfolio
# skipped1973-05-01 00:00:00on 4th portfolio
# skipped1973-06-01 00:00:00on 4th portfolio

# %% [markdown]
# # Testing scripts
# ## Getting equal weight portfolios

# %%
import form_portfolio

# %%
files = ['FF_M_VOL', 'MKTCAP_M']
investable_universe_npy='investable_universe_0221.npy'
nyse_permno_xlsx='NYSE PERMNO.xlsx'
list_execute=[['FF_M_VOL_lag']]
nyse_break=False
startdate=datetime.datetime(1965, 2, 1)
enddate=datetime.datetime(2016, 12, 1)

# %%
form_portfolio.form_portfolio(files, investable_universe_npy, nyse_permno_xlsx, list_execute,
                             nyse_break, startdate, enddate, value_weight=False)
# Out:
# Portfolio formed for _FF_M_VOL_lag

# %%
temp = pd.read_pickle(setting.datapath_pf_weight + 'pfweight_FF_M_VOL_lag_False1965-02-2016-12equal.pkl')

# %%
temp[datetime.datetime(1965, 2, 1)][0]
# Out:
# PERMNO
# 16432    0.003096
# 24627    0.003096
# 24678    0.003096
# 32889    0.003096
# 24723    0.003096
# 16555    0.003096
# 16571    0.003096
# 24766    0.003096
# 16598    0.003096
# 24811    0.003096
# 33056    0.003096
# 24870    0.003096
# 33099    0.003096
# 16723    0.003096
# 16758    0.003096
# 16870    0.003096
# 25072    0.003096
# 25099    0.003096
# 25283    0.003096
# 25291    0.003096
# 25419    0.003096
# 25443    0.003096
# 17267    0.003096
# 17320    0.003096
# 25515    0.003096
# 25523    0.003096
# 25611    0.003096
# 25662    0.003096
# 17478    0.003096
# 25726    0.003096
#            ...
# 15720    0.003096
# 23931    0.003096
# 15747    0.003096
# 23990    0.003096
# 15819    0.003096
# 24037    0.003096
# 24053    0.003096
# 24061    0.003096
# 24109    0.003096
# 15923    0.003096
# 24117    0.003096
# 15966    0.003096
# 24184    0.003096
# 24192    0.003096
# 24205    0.003096
# 24213    0.003096
# 16029    0.003096
# 24221    0.003096
# 24256    0.003096
# 24280    0.003096
# 24301    0.003096
# 24328    0.003096
# 32598    0.003096
# 24440    0.003096
# 16272    0.003096
# 24467    0.003096
# 24491    0.003096
# 24539    0.003096
# 16360    0.003096
# 24571    0.003096
# Name: weight, dtype: float64

# %%
np.sum(temp[datetime.datetime(2005, 1, 1)][15])
# Out:
# 1.0

# %% [markdown]
# # 4. Specific Quantile Portfolio Analysis

# %%
% matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
def heatmap(df):
    fig, ax = plt.subplots()
    # setting
#     heatmap = ax.pcolor(df, cmap=plt.cm.Blues, alpha=0.8)
    heatmap = ax.pcolor(df, alpha=0.8)

    # turn off the frame
    ax.set_frame_on(False)

    # put the major ticks at the middle of each cell
    ax.set_yticks(np.arange(df.shape[0]) + 1, minor=False)
    ax.set_xticks(np.arange(df.shape[1]) + 1, minor=False)

    # want a more natural, table-like display
    ax.invert_yaxis()
    ax.xaxis.tick_top()


    # note I could have used nba_sort.columns but made "labels" instead
    ax.set_xticklabels(df.columns, minor=False)
    ax.set_yticklabels(df.index, minor=False)

# %% [markdown]
# # The tasks
#
# 1) Long short portfolio returns, t-stat, alpha
#
# 2) Long short portfolio returns after short fee, t-stat, alpha
#
# 3) Long short portfolio returns after short fee and transaction costs(3 scenarios), t-stat, alpha
#
# 4) combo with BAB portfolio
#
# Modules:
#
# 1) transaction costs embeded
#
# 2) cumulative return plot

# %%
fee_pivot=read_in_signal('IndicativeFee')

# %%
def review_weight_chg(analysis_robot):
    """Caluclate the total absolute weight change at the end of each month
    """
    pfweight = analysis_robot.pfweight
    return_pivot = analysis_robot.return_pivot  # return pivot
    return_series = analysis_robot.return_series
    
    t_cost = pd.DataFrame(index=return_series.index, columns=return_series.columns)
    
    for today_index in t_cost.index[:-1]:
        today_date = today_index.to_timestamp()
        next_month = today_date + dateutil.relativedelta.relativedelta(months=1)

        weight = pfweight[today_date]
        weight_nextm = pfweight[next_month]

        month_return = return_pivot.ix[today_date]
        for i in t_cost.columns:
            m_return_in = month_return.ix[weight[i-1].index].dropna()
            portfolio = pd.concat([weight[i-1], m_return_in], axis=1).dropna()
            portfolio.columns = ['weight', 'M_RET']

            portfolio['new weight']=(1.0+portfolio['M_RET'])*portfolio['weight']
            portfolio['new weight']=portfolio['new weight']/portfolio['new weight'].sum()

            port_change=pd.concat([weight_nextm[i-1],portfolio['new weight']],axis=1)
            port_change=port_change.fillna(0)
            port_change['rebalance']=np.abs(port_change['new weight']-port_change['weight'])
            weight_change=port_change['rebalance'].sum()

            t_cost.loc[today_date,i]=weight_change
    
    # final date closure
    today_date = t_cost.index[-1]
    t_cost.loc[today_date, :] = 1.0
    
    return t_cost

# %%
import scipy.optimize as opt

def threshold_cost(m_cost, ret, turnover):
    transact_cost = turnover*m_cost
    ret_cost = ret - (transact_cost[1] + transact_cost[5])
    return np.abs(np.mean(ret_cost))


def alpha_threshold_cost(m_cost, ret, turnover, ff_mthly, ffalpha):
    transact_cost = turnover*m_cost
    ret_cost = pd.Series(ret - (transact_cost[1] + transact_cost[5]), dtype=float)
    if ffalpha:
        return np.abs(alpha_test(ret_cost, ff_mthly, minusRF=False, ffalpha=True)[0])
    else:
        return np.abs(alpha_test(ret_cost, ff_mthly, minusRF=False, ffalpha=False)[0])

# %%
def tcost_analysis(longshort_ret, turnover, ff_mthly, startdate, enddate, cost_list):
    
    m_longshort_ret = select_range(longshort_ret, startdate, enddate)
    m_turnover = select_range(turnover, startdate, enddate)
    
    m_result = np.zeros((6, 5))
    for i in range(len(cost_list)):
        m_cost = cost_list[i]
        m_transact_cost = m_turnover*m_cost
        m_ret_cost = pd.Series(m_longshort_ret - (m_transact_cost[1]+m_transact_cost[5]), dtype=float)
        m_result[0:2, i] = mean_t_stat(m_ret_cost)
        m_result[2:4, i] = alpha_test(m_ret_cost, ff_mthly, minusRF=False, ffalpha=False)
        m_result[4:6, i] = alpha_test(m_ret_cost, ff_mthly, minusRF=False, ffalpha=True)
        
    
    m_result[0, 4] = opt.minimize(threshold_cost, 0.002, args=(m_longshort_ret, m_turnover), method='Nelder-Mead').x[0]
    m_result[2, 4] = opt.minimize(alpha_threshold_cost, 0.002, 
                                  args=(m_longshort_ret, m_turnover, ff_mthly, False), method='Nelder-Mead').x[0]
    m_result[4, 4] = opt.minimize(alpha_threshold_cost, 0.002, 
                                  args=(m_longshort_ret, m_turnover, ff_mthly, True), method='Nelder-Mead').x[0]

    m_result = pd.DataFrame(m_result,index=['Arithmetic Mean', 't-stat', 'CAPM alpha', 't-stat', 'FF3 alpha', 't-stat'],
                            columns=[['cost']*5, cost_list+['Threshold Cost']])
    
    return m_result

# %% [markdown]
# ### Idiosyncratic Volatility Trading Costs

# %%
cost_list = [0, 0.004, 0.008, 0.02]

# %%
analysis_robot = post_data_analysis('pfweight_FF_M_VOL_lag_False1965-02-2016-12')

# %%
long_pf = analysis_robot.return_series[1] 
short_pf =  analysis_robot.return_series[5]
longshort_ret = long_pf - short_pf
turnover = review_weight_chg(analysis_robot)

# %%
turnover.mean(axis=0)
# Out:
# 1    0.604990
# 2    1.304598
# 3    1.472778
# 4    1.520993
# 5    1.405418
# dtype: float64

# %%
tcost_analysis(longshort_ret, turnover, analysis_robot.ff_mthly, datetime.datetime(1965, 2, 1), 
               datetime.datetime(2003, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008     0.02 Threshold Cost
# Arithmetic Mean  0.0066 -0.0013 -0.0091  -0.0328         0.0034
# t-stat           1.8805 -0.3553 -2.5955  -9.2287         0.0000
# CAPM alpha       0.0099  0.0020 -0.0059  -0.0296         0.0050
# t-stat           3.1638  0.6314 -1.9035  -9.4051         0.0000
# FF3 alpha        0.0099  0.0020 -0.0059  -0.0296         0.0050
# t-stat           5.0341  1.0143 -2.9473 -14.0662         0.0000

# %%
tcost_analysis(longshort_ret, turnover, analysis_robot.ff_mthly, datetime.datetime(1980, 1, 1), 
               datetime.datetime(2003, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008    0.02 Threshold Cost
# Arithmetic Mean  0.0111  0.0029 -0.0053 -0.0298         0.0054
# t-stat           2.7972  0.7312 -1.3199 -7.2639         0.0000
# CAPM alpha       0.0160  0.0078 -0.0004 -0.0249         0.0078
# t-stat           4.2902  2.0885 -0.1000 -6.4869         0.0000
# FF3 alpha        0.0125  0.0043 -0.0039 -0.0284         0.0061
# t-stat           4.5735  1.5757 -1.4044 -9.9782         0.0000

# %%
tcost_analysis(longshort_ret, turnover, analysis_robot.ff_mthly, datetime.datetime(2004, 1, 1), 
               datetime.datetime(2016, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008     0.02 Threshold Cost
# Arithmetic Mean  0.0009 -0.0076 -0.0161  -0.0416         0.0004
# t-stat           0.2794 -2.4934 -5.2772 -13.6605         0.0000
# CAPM alpha       0.0051 -0.0034 -0.0119  -0.0374         0.0024
# t-stat           2.1183 -1.4099 -4.9329 -15.4063         0.0000
# FF3 alpha        0.0051 -0.0034 -0.0119  -0.0375         0.0024
# t-stat           2.2945 -1.5466 -5.3534 -16.5029         0.0000

# %%
# tcost_analysis(longshort_ret, turnover, analysis_robot.ff_mthly, datetime.datetime(2001, 1, 1), 
#                datetime.datetime(2016, 12, 31), cost_list).round(4)

# %%
startdate = datetime.datetime(2004, 1, 1)
enddate = datetime.datetime(2016, 12, 1)
pf_fee = review_pf_signal(startdate, enddate, analysis_robot.pfweight, fee_pivot)

longshort_ret_sfee = select_range(longshort_ret, datetime.datetime(2004, 1, 1), 
                                  datetime.datetime(2016, 12, 31)) - pf_fee[5]/12.0

# %%
tcost_analysis(longshort_ret_sfee, turnover, analysis_robot.ff_mthly, datetime.datetime(2004, 1, 1), 
               datetime.datetime(2016, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008     0.02 Threshold Cost
# Arithmetic Mean -0.0003 -0.0088 -0.0173  -0.0428        -0.0002
# t-stat          -0.1034 -2.9091 -5.7265 -14.2139         0.0000
# CAPM alpha       0.0039 -0.0046 -0.0131  -0.0386         0.0018
# t-stat           1.6580 -1.9234 -5.4998 -16.1315         0.0000
# FF3 alpha        0.0039 -0.0046 -0.0131  -0.0386         0.0018
# t-stat           1.7943 -2.1066 -5.9725 -17.2906         0.0000

# %%
# tcost_analysis(longshort_ret_sfee, turnover, analysis_robot.ff_mthly, datetime.datetime(2004, 1, 1), 
#                datetime.datetime(2016, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008     0.02 Threshold Cost
# Arithmetic Mean -0.0003 -0.0088 -0.0173  -0.0428        -0.0002
# t-stat          -0.1034 -2.9091 -5.7265 -14.2139         0.0000
# CAPM alpha       0.0039 -0.0046 -0.0131  -0.0386         0.0018
# t-stat           1.6580 -1.9234 -5.4998 -16.1315         0.0000
# FF3 alpha        0.0039 -0.0046 -0.0131  -0.0386         0.0018
# t-stat           1.7943 -2.1066 -5.9725 -17.2906         0.0000

# %% [markdown]
# ### Total Vol Trading Costs Analysis

# %%
analysis_robot2 = post_data_analysis('pfweight_M_VOL_lag_False1965-02-2016-12')

# %%
long_pf2 = analysis_robot2.return_series[1] 
short_pf2 =  analysis_robot2.return_series[5]
longshort_ret2 = long_pf2 - short_pf2
turnover2 = review_weight_chg(analysis_robot2)

# %%
tcost_analysis(longshort_ret2, turnover2, analysis_robot2.ff_mthly, datetime.datetime(1965, 2, 1), 
               datetime.datetime(2016, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008     0.02 Threshold Cost
# Arithmetic Mean  0.0054 -0.0031 -0.0115  -0.0367         0.0026
# t-stat           1.7109 -0.9714 -3.6364 -11.3835         0.0000
# CAPM alpha       0.0098  0.0014 -0.0071  -0.0323         0.0047
# t-stat           3.6790  0.5091 -2.6167 -11.5713         0.0000
# FF3 alpha        0.0094  0.0010 -0.0074  -0.0328         0.0045
# t-stat           4.7095  0.4862 -3.5615 -14.4597         0.0000

# %%
cost_list = [0, 0.002, 0.004, 0.008]

# %%
tcost_analysis(longshort_ret2, turnover2, analysis_robot2.ff_mthly, datetime.datetime(1965, 2, 1), 
               datetime.datetime(2003, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.002   0.004   0.008 Threshold Cost
# Arithmetic Mean  0.0059  0.0016 -0.0026 -0.0112         0.0028
# t-stat           1.4719  0.4058 -0.6561 -2.7624         0.0000
# CAPM alpha       0.0098  0.0055  0.0012 -0.0073         0.0046
# t-stat           2.8351  1.5925  0.3570 -2.0862         0.0000
# FF3 alpha        0.0084  0.0041 -0.0002 -0.0088         0.0039
# t-stat           3.6407  1.7645 -0.0840 -3.6805         0.0000

# %%
tcost_analysis(longshort_ret2, turnover2, analysis_robot2.ff_mthly, datetime.datetime(1980, 1, 1), 
               datetime.datetime(2003, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.002   0.004   0.008 Threshold Cost
# Arithmetic Mean  0.0106  0.0062  0.0018 -0.0070         0.0048
# t-stat           2.3266  1.3542  0.3905 -1.5059         0.0000
# CAPM alpha       0.0167  0.0123  0.0079 -0.0009         0.0076
# t-stat           4.1110  3.0057  1.9166 -0.2093         0.0000
# FF3 alpha        0.0117  0.0072  0.0028 -0.0060         0.0053
# t-stat           3.8798  2.3874  0.9207 -1.9271         0.0000

# %%
tcost_analysis(longshort_ret2, turnover2, analysis_robot2.ff_mthly, datetime.datetime(1965, 2, 1), 
               datetime.datetime(2000, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008     0.02 Threshold Cost
# Arithmetic Mean  0.0053 -0.0032 -0.0118  -0.0374         0.0025
# t-stat           1.4587 -0.8786 -3.2084  -9.9892         0.0000
# CAPM alpha       0.0092  0.0006 -0.0080  -0.0337         0.0043
# t-stat           2.8379  0.1873 -2.4485 -10.0974         0.0000
# FF3 alpha        0.0074 -0.0012 -0.0098  -0.0355         0.0035
# t-stat           3.6062 -0.5719 -4.5986 -15.3351         0.0000

# %%
tcost_analysis(longshort_ret2, turnover2, analysis_robot2.ff_mthly, datetime.datetime(2001, 1, 1), 
               datetime.datetime(2016, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008    0.02 Threshold Cost
# Arithmetic Mean  0.0053 -0.0028 -0.0109 -0.0353         0.0027
# t-stat           1.0111 -0.5250 -2.0410 -6.4375         0.0000
# CAPM alpha       0.0110  0.0029 -0.0052 -0.0295         0.0055
# t-stat           3.0770  0.8063 -1.4101 -7.6640         0.0000
# FF3 alpha        0.0119  0.0038 -0.0044 -0.0288         0.0059
# t-stat           4.0107  1.2444 -1.4065 -8.6049         0.0000

# %% [markdown]
# ### After short fee return

# %%
startdate = datetime.datetime(2004, 1, 1)
enddate = datetime.datetime(2016, 12, 1)
pf_fee2 = review_pf_signal(startdate, enddate, analysis_robot2.pfweight, fee_pivot)

longshort_ret_sfee2 = select_range(longshort_ret2, datetime.datetime(2004, 1, 1), 
                                  datetime.datetime(2016, 12, 31)) - pf_fee2[5]/12.0

# %%
tcost_analysis(longshort_ret2, turnover2, analysis_robot2.ff_mthly, datetime.datetime(2004, 1, 1), 
               datetime.datetime(2016, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008     0.02 Threshold Cost
# Arithmetic Mean  0.0035 -0.0046 -0.0127  -0.0371         0.0017
# t-stat           0.9157 -1.2041 -3.3421  -9.7319         0.0000
# CAPM alpha       0.0095  0.0014 -0.0067  -0.0311         0.0047
# t-stat           4.2126  0.6147 -2.9492 -12.9832         0.0000
# FF3 alpha        0.0094  0.0013 -0.0068  -0.0312         0.0047
# t-stat           4.5017  0.6147 -3.1012 -12.9333         0.0000

# %%
tcost_analysis(longshort_ret_sfee2, turnover2, analysis_robot2.ff_mthly, datetime.datetime(2004, 1, 1), 
               datetime.datetime(2016, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008     0.02 Threshold Cost
# Arithmetic Mean  0.0025 -0.0056 -0.0138  -0.0381         0.0012
# t-stat           0.6477 -1.4824 -3.6296 -10.0379         0.0000
# CAPM alpha       0.0085  0.0004 -0.0078  -0.0321         0.0042
# t-stat           3.8060  0.1593 -3.4462 -13.5507         0.0000
# FF3 alpha        0.0084  0.0003 -0.0078  -0.0322         0.0042
# t-stat           4.0457  0.1317 -3.6009 -13.4326         0.0000

# %% [markdown]
# ### Long term vol trading cost
# #### - Idio volatility results

# %%
startdate = datetime.datetime(2004, 1, 1)
enddate = datetime.datetime(2016, 12, 1)

# %%
analysis_robot3 = post_data_analysis('pfweight_FF_L_VOL_24M_lag_lag_False1965-02-2016-12')

# %%
longshort_ret3 = analysis_robot3.return_series[1] -analysis_robot3.return_series[5]
turnover3 = review_weight_chg(analysis_robot3)

# %%
turnover3.mean(axis=0)
# Out:
# 1    0.201045
# 2    0.476756
# 3    0.510398
# 4    0.450908
# 5    0.309810
# dtype: float64

# %%
pf_fee3 = review_pf_signal(startdate, enddate, analysis_robot3.pfweight, fee_pivot)
longshort_ret_sfee3 = select_range(longshort_ret3, startdate, enddate) - pf_fee3[5]/12.0

# %%
tcost_analysis(longshort_ret3, turnover3, analysis_robot3.ff_mthly, datetime.datetime(1965, 2, 1), 
               datetime.datetime(2003, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008    0.02 Threshold Cost
# Arithmetic Mean  0.0016 -0.0006 -0.0028 -0.0092         0.0029
# t-stat           0.4276 -0.1622 -0.7600 -2.5817         0.0000
# CAPM alpha       0.0050  0.0028  0.0006 -0.0059         0.0092
# t-stat           1.5441  0.8721  0.1985 -1.8093         0.0000
# FF3 alpha        0.0037  0.0015 -0.0007 -0.0071         0.0068
# t-stat           1.6510  0.6769 -0.2995 -3.1796         0.0000

# %%
tcost_analysis(longshort_ret3, turnover3, analysis_robot3.ff_mthly, datetime.datetime(1980, 1, 1), 
               datetime.datetime(2003, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008    0.02 Threshold Cost
# Arithmetic Mean  0.0041  0.0019 -0.0003 -0.0069         0.0075
# t-stat           0.8912  0.4156 -0.0610 -1.4809         0.0000
# CAPM alpha       0.0095  0.0073  0.0051 -0.0016         0.0172
# t-stat           2.2514  1.7203  1.1919 -0.3636         0.0000
# FF3 alpha        0.0046  0.0024  0.0002 -0.0064         0.0083
# t-stat           1.4568  0.7560  0.0500 -2.0640         0.0000

# %%
# turnover3

# %%
tcost_analysis(longshort_ret3, turnover3, analysis_robot3.ff_mthly, datetime.datetime(2004, 1, 1), 
               datetime.datetime(2016, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008    0.02 Threshold Cost
# Arithmetic Mean  0.0005 -0.0012 -0.0028 -0.0078         0.0011
# t-stat           0.1535 -0.3823 -0.9203 -2.4667         0.0000
# CAPM alpha       0.0040  0.0024  0.0007 -0.0044         0.0096
# t-stat           1.4092  0.8047  0.2238 -1.3460         0.0000
# FF3 alpha        0.0041  0.0024  0.0007 -0.0044         0.0097
# t-stat           1.6038  0.9283  0.2646 -1.5797         0.0000

# %%
tcost_analysis(longshort_ret_sfee3, turnover3, analysis_robot3.ff_mthly, datetime.datetime(2004, 1, 1), 
               datetime.datetime(2016, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008    0.02 Threshold Cost
# Arithmetic Mean -0.0009 -0.0026 -0.0042 -0.0092        -0.0022
# t-stat          -0.2936 -0.8416 -1.3916 -2.9684         0.0000
# CAPM alpha       0.0027  0.0010 -0.0007 -0.0058         0.0064
# t-stat           0.9500  0.3423 -0.2405 -1.8069         0.0000
# FF3 alpha        0.0027  0.0010 -0.0007 -0.0058         0.0064
# t-stat           1.0739  0.3952 -0.2706 -2.1129         0.0000

# %% [markdown]
# #### Total Volatilities Results

# %%
analysis_robot4 = post_data_analysis('pfweight_L_VOL_24M_lag_lag_False1965-02-2016-12')

# %%
longshort_ret4 = analysis_robot4.return_series[1] -analysis_robot4.return_series[5]
turnover4 = review_weight_chg(analysis_robot4)

# %%
turnover4.mean(axis=0)
# Out:
# 1    0.097037
# 2    0.265737
# 3    0.321848
# 4    0.318687
# 5    0.242539
# dtype: float64

# %%
pf_fee4 = review_pf_signal(startdate, enddate, analysis_robot4.pfweight, fee_pivot)
longshort_ret_sfee4 = select_range(longshort_ret4, startdate, enddate) - pf_fee4[5]/12.0

# %%
tcost_analysis(longshort_ret4, turnover4, analysis_robot4.ff_mthly, datetime.datetime(1965, 2, 1), 
               datetime.datetime(2016, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008    0.02 Threshold Cost
# Arithmetic Mean  0.0021  0.0008 -0.0006 -0.0046         0.0064
# t-stat           0.6668  0.2464 -0.1767 -1.4609         0.0000
# CAPM alpha       0.0067  0.0053  0.0040 -0.0001         0.0197
# t-stat           2.3362  1.8606  1.3849 -0.0395         0.0000
# FF3 alpha        0.0058  0.0044  0.0031 -0.0010         0.0170
# t-stat           3.0294  2.3163  1.6025 -0.5310         0.0000

# %%
tcost_analysis(longshort_ret_sfee4, turnover4, analysis_robot4.ff_mthly, datetime.datetime(2004, 1, 1), 
               datetime.datetime(2016, 12, 31), cost_list).round(4)
# Out:
#                    cost
#                       0   0.004   0.008    0.02 Threshold Cost
# Arithmetic Mean -0.0019 -0.0032 -0.0045 -0.0083        -0.0059
# t-stat          -0.5013 -0.8473 -1.1986 -2.2783         0.0000
# CAPM alpha       0.0034  0.0021  0.0008 -0.0031         0.0104
# t-stat           0.8647  0.5292  0.1972 -0.7714         0.0000
# FF3 alpha        0.0034  0.0021  0.0008 -0.0032         0.0103
# t-stat           1.1156  0.6818  0.2485 -1.0331         0.0000

# %% [markdown]
# ### Time varying results

# %%
def time_vary_analyze(longshort_ret, date_list):
    time_result = np.zeros((8, len(date_list)))
    for i in range(len(date_list)):
        m_longshort_ret = select_range(longshort_ret, date_list[i][0], date_list[i][1])

        time_result[:2, i] = mean_t_stat(m_longshort_ret)
        time_result[2:4, i] = alpha_test(m_longshort_ret, analysis_robot.ff_mthly, minusRF=False, ffalpha=False, j=0)
        time_result[4:6, i] = alpha_test(m_longshort_ret, analysis_robot.ff_mthly, minusRF=False, ffalpha=False, j=1)
        time_result[6:8, i] = alpha_test(m_longshort_ret, analysis_robot.ff_mthly, minusRF=False, ffalpha=True, j=0)
        
    time_result = pd.DataFrame(time_result, 
                               index=['Mean_ret', 't-stat', 'CAPM alpha', 't-stat',
                                      'CAPM beta', 't-stat', 'FF3 alpha', 't-stat'],
                               columns=[str(date_list[i][0])[:8]+str(date_list[i][1])[:7] for i in range(len(date_list))])
    return time_result

# %%
# idio vol
date_list = [[datetime.datetime(1980, 1, 1), datetime.datetime(2003, 12, 31)],
            [datetime.datetime(2004, 1, 1), datetime.datetime(2016, 12, 31)],
            [datetime.datetime(1965, 2, 1), datetime.datetime(2016, 12, 31)]]

time_vary_analyze(longshort_ret, date_list)
# Out:
#             1980-01-2003-12  2004-01-2016-12  1965-02-2016-12
# Mean_ret           0.011063         0.000858         0.005256
# t-stat             2.797231         0.279388         1.886180
# CAPM alpha         0.015981         0.005108         0.008817
# t-stat             4.290156         2.118284         3.595046
# CAPM beta         -0.773374        -0.671570        -0.728437
# t-stat            -4.463364        -5.122690        -7.683435
# FF3 alpha          0.012508         0.005074         0.008909
# t-stat             4.573483         2.294523         5.419214

# %%
mean_t_stat(select_range(analysis_robot.ff_mthly['MKT_RF'], datetime.datetime(1980, 1, 1), datetime.datetime(2003, 12, 31)))
# Out:
# [0.0063581881533101041, 2.4704096331717373]

# %%
# total vol
time_vary_analyze(longshort_ret=longshort_ret2, date_list=date_list)
# Out:
#             1980-01-2003-12  2004-01-2016-12  1965-02-2016-12
# Mean_ret           0.010561         0.003517         0.005364
# t-stat             2.326635         0.915659         1.710934
# CAPM alpha         0.016692         0.009511         0.009787
# t-stat             4.110966         4.212639         3.678997
# CAPM beta         -0.964244        -0.947014        -0.904936
# t-stat            -5.112865        -6.576579        -8.668318
# FF3 alpha          0.011662         0.009435         0.009432
# t-stat             3.879833         4.501713         4.709503

# %% [markdown]
# ### Plotting of results

# %%
longshort_ret2.cumsum().plot(label='Total Volatility')
longshort_ret.cumsum().plot(label='Idiosyncratic Volatility')
longshort_ret3.cumsum().plot(label='Idiosyncratic Voatility (long)')
longshort_ret4.cumsum().plot(label='Total Voatility (long)')
plt.vlines(datetime.datetime(2004, 1, 1), ymin=-1, ymax=4, linestyles='dashed', label='Jan 2004')
plt.legend(loc='best',prop={'size':8})
plt.ylabel('Cumulative Return')
plt.title('Volatility Factor Portfolio Return [1-5]')
plt.savefig(setting.outputpath + 'graph_long_short/'+'vol_factor_cumret_combine.png', bbox='tight')

# %%
plt.figure(figsize=(8, 7));
plt.subplot(2, 1, 1)
longshort_ret2.cumsum().plot(label='Cumulative Return')
plt.vlines(datetime.datetime(2004, 1, 1), ymin=-1, ymax=4, linestyles='dashed', label='Jan 2004')
plt.legend(loc='best')
plt.title('Total Volatility [1-5] Portfolio')

plt.subplot(2, 1, 2)
longshort_ret.cumsum().plot(label='Cumulative Return')
plt.vlines(datetime.datetime(2004, 1, 1), ymin=-1, ymax=4, linestyles='dashed', label='Jan 2004')
plt.legend(loc='best')
plt.title('Idiosyncratic Volatility [1-5] Portfolio')

plt.savefig(setting.outputpath + 'graph_long_short/'+'vol_factor_cumret.png', bbox='tight')

# %% [markdown]
# # Cumulative Plot

# %%
cost = [0.0025, 0.0040, 0.0040, 0.0040, 0.0030]

# %%
transact_cost = temp*np.array(cost)

# %%
long_pf = analysis_robot.return_series[1] 
short_pf =  analysis_robot.return_series[5]
longshort_ret = long_pf - short_pf

# %%
transact_cost = transact_cost[1] + transact_cost[5] 
longshort_add_cost = (longshort_ret - transact_cost)

# %%
scipy.stats.mstats.gmean(longshort_ret.values+1.0)
# Out:
# 1.0047509576364781

# %%
alpha_test(pd.Series(longshort_ret, dtype=float), analysis_robot.ff_mthly, minusRF=True, ffalpha=True)
# Out:
# [0.0049576120231192098, 3.0216198544608215]

# %%
longshort_ret.cumsum().plot()
(transact_cost).cumsum().plot()

# %%
longshort_ret.ix[longshort_ret.index > datetime.datetime(2004, 1, 1)].cumsum().plot()
long_pf.ix[long_pf.index > datetime.datetime(2004, 1, 1)].cumsum().plot()
short_pf.ix[short_pf.index > datetime.datetime(2004, 1, 1)].cumsum().plot()
plt.legend(['longshort', 'long', 'short'], loc='best')
plt.title('Equal Weighted ranked by Idio Vol')
plt.savefig(setting.outputpath+'graph_long_short/'+'ffvol_eq_aft2004.png')

# %%
longshort_ret.cumsum().plot()
long_pf.cumsum().plot()
short_pf.cumsum().plot()
plt.legend(['longshort', 'long', 'short'], loc='best')
plt.title('Equal Weighted ranked by Idio Vol')
plt.savefig(setting.outputpath+'graph_long_short/'+'ffvol_eq.png')

# %%
analysis_robot.return_series.cumsum().plot()
plt.title('Equal Weighted Idio Vol Portfolio')

# %%
long_pf = analysis_robot2.return_series[1] 
short_pf =  analysis_robot2.return_series[5]
longshort_ret = long_pf - short_pf

# %%
longshort_ret.ix[longshort_ret.index > datetime.datetime(2004, 1, 1)].cumsum().plot()
long_pf.ix[long_pf.index > datetime.datetime(2004, 1, 1)].cumsum().plot()
short_pf.ix[short_pf.index > datetime.datetime(2004, 1, 1)].cumsum().plot()
plt.legend(['longshort', 'long', 'short'], loc='best')
plt.title('Value Weighted ranked by Idio Vol')
plt.savefig(setting.outputpath+'graph_long_short/'+'ffvol_vw_aft2004.png')

# %%
longshort_ret.cumsum().plot()
long_pf.cumsum().plot()
short_pf.cumsum().plot()
plt.legend(['longshort', 'long', 'short'], loc='best')
plt.title('Equal Weighted ranked by Idio Vol')
plt.savefig(setting.outputpath+'graph_long_short/'+'ffvol_vw.png')

# %%
long_pf = analysis_robot2.return_series[1] 
short_pf =  analysis_robot2.return_series[5]
longshort_ret = long_pf - short_pf

# %%
analysis_robot2.return_series.cumsum().plot()
plt.title('Value Weighted Tot Vol Portfolio')

# %%
longshort_ret.ix[longshort_ret.index > datetime.datetime(2004, 1, 1)].cumsum().plot()
long_pf.ix[long_pf.index > datetime.datetime(2004, 1, 1)].cumsum().plot()
short_pf.ix[short_pf.index > datetime.datetime(2004, 1, 1)].cumsum().plot()
plt.legend(['longshort', 'long', 'short'], loc='best')
plt.title('Value Weighted ranked by Tot Vol')

# %%
longshort_ret.cumsum().plot()
long_pf.cumsum().plot()
short_pf.cumsum().plot()
plt.legend(['longshort', 'long', 'short'], loc='best')
plt.title('Value Weighted ranked by Tot Vol')
